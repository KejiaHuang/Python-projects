# %% [markdown]
# ## Use random foreset to get the type of resaurant based on review

# %% [markdown]
# ### data1 and data0 include all buessine id and review with type number
# ### 1 means indian food
# ### 0 means none indian food

# %%
import pandas as pd       
data1 = pd.read_csv("yelp_reviews_1.csv")
data0 = pd.read_csv("yelp_reviews_0.csv")

# %% [markdown]
# ### build train dataset and test dataset

# %%
i_0, j_0 = data0.shape
i_1, j_1 = data1.shape

train =  [data0.head(int(i_0*0.8)),data1.head(int(i_1*0.8))]
test =  [data0.tail(i_0-int(i_0*0.8)),data1.tail(i_1 - (int(i_1*0.8)))]
train = pd.concat(train)
test = pd.concat(test)
train = train.reset_index() 
test = test.reset_index()

# %% [markdown]
# ## example about the method of cheaning review

# %%
# Import BeautifulSoup 
from bs4 import BeautifulSoup             

# Initialize the BeautifulSoup object on a single review     
example1 = BeautifulSoup(train["Review"][0])  

# Print the raw review and then the output of get_text(), for 
# comparison
print (train["Review"][0][:1000])

print (example1.get_text()[:1000])
# Out:
# Working in Fifth Avenue Place downtown affords me a lot of different coffee options. Ranging from multiple Crazy Mocha locations, Starbucks, burnt swill for free, and little individual places like this.   Fifth Avenue Beanery is a kiosk type place on the first floor of the building. It says "coffee roasters" but unless they're roasting their own beans off site, I haven't seen any roasting equipment. There is one woman who is there regularly and a few others who are there on and off during different days/times during the week.  They offer a re-useable mug to save on waste and it also provides you a small discount on your drinks. Admittedly I've only had the pumpkin pie latte, the salted caramel latte, and a black coffee. The drinks are always hot and the espresso is strong.  If you happen into the building, make sure to have cash (no cards) and stop by. Fifth Avenue Beanery is the type of coffee spot that suits convenience over quality, putting it on par with the Crazy Mochas and Starbu
# Working in Fifth Avenue Place downtown affords me a lot of different coffee options. Ranging from multiple Crazy Mocha locations, Starbucks, burnt swill for free, and little individual places like this.   Fifth Avenue Beanery is a kiosk type place on the first floor of the building. It says "coffee roasters" but unless they're roasting their own beans off site, I haven't seen any roasting equipment. There is one woman who is there regularly and a few others who are there on and off during different days/times during the week.  They offer a re-useable mug to save on waste and it also provides you a small discount on your drinks. Admittedly I've only had the pumpkin pie latte, the salted caramel latte, and a black coffee. The drinks are always hot and the espresso is strong.  If you happen into the building, make sure to have cash (no cards) and stop by. Fifth Avenue Beanery is the type of coffee spot that suits convenience over quality, putting it on par with the Crazy Mochas and Starbu
# /usr/local/lib/python3.4/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /usr/lib/python3.4/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
import re
# Use regular expressions to do a find-and-replace
letters_only = re.sub("[^a-zA-Z]",           # The pattern to search for
                      " ",                   # The pattern to replace it with
                      example1.get_text() )  # The text to search
print (letters_only[:1000])
# Out:
# Working in Fifth Avenue Place downtown affords me a lot of different coffee options  Ranging from multiple Crazy Mocha locations  Starbucks  burnt swill for free  and little individual places like this    Fifth Avenue Beanery is a kiosk type place on the first floor of the building  It says  coffee roasters  but unless they re roasting their own beans off site  I haven t seen any roasting equipment  There is one woman who is there regularly and a few others who are there on and off during different days times during the week   They offer a re useable mug to save on waste and it also provides you a small discount on your drinks  Admittedly I ve only had the pumpkin pie latte  the salted caramel latte  and a black coffee  The drinks are always hot and the espresso is strong   If you happen into the building  make sure to have cash  no cards  and stop by  Fifth Avenue Beanery is the type of coffee spot that suits convenience over quality  putting it on par with the Crazy Mochas and Starbu

# %%
import nltk

# %%
lower_case = letters_only.lower()        # Convert to lower case
words = lower_case.split()    # Split into words
words[:20]
# Out:
# ['working',
#  'in',
#  'fifth',
#  'avenue',
#  'place',
#  'downtown',
#  'affords',
#  'me',
#  'a',
#  'lot',
#  'of',
#  'different',
#  'coffee',
#  'options',
#  'ranging',
#  'from',
#  'multiple',
#  'crazy',
#  'mocha',
#  'locations']

# %%
from nltk.tag import pos_tag


tagged_sent = pos_tag(words)
tagged_sent
#use NLTK to get the type of the word and only leave noun
wordss = [word for word,pos in tagged_sent if pos == 'NNS']
wordss[:20]
# Out:
# ['affords',
#  'options',
#  'locations',
#  'starbucks',
#  'places',
#  'roasters',
#  'beans',
#  't',
#  'others',
#  'days',
#  'times',
#  'drinks',
#  'drinks',
#  'cards',
#  'suits',
#  'starbucks',
#  'prices',
#  'places',
#  'baristas',
#  'chains']

# %%
from nltk.tag import pos_tag
import nltk
from bs4 import BeautifulSoup    
import re
from nltk.corpus import stopwords # Import the stop word list
print (stopwords.words("english") )
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', 'should', 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', 'couldn', 'didn', 'doesn', 'hadn', 'hasn', 'haven', 'isn', 'ma', 'mightn', 'mustn', 'needn', 'shan', 'shouldn', 'wasn', 'weren', 'won', 'wouldn']

# %%
# Remove stop words from "words"
words = [w for w in words if not w in stopwords.words("english")]
stopwords.words("english")[:20]
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  'her',
#  'hers']

# %% [markdown]
# ## text process function

# %%
from nltk.tag import pos_tag
import nltk
from bs4 import BeautifulSoup    
import re
from nltk.corpus import stopwords # Import the stop word list
def review_to_words( raw_review ):
    # Function to convert a raw review to a string of words
    # The input is a single string (a raw movie review), and 
    # the output is a single string (a preprocessed movie review)
    #
    
    # 1. Remove HTML
    review_text = BeautifulSoup(raw_review).get_text() 
    #
    # 2. Remove non-letters        
    letters_only = re.sub("[^a-zA-Z]", " ", review_text) 
    #
    # 3. Convert to lower case, split into individual words
    words = letters_only.lower().split()                             
    #
    # 4. In Python, searching a set is much faster than searching
    #   a list, so convert the stop words to a set
    stops = set(stopwords.words("english"))                  
    # 
    # 5. Remove stop words
    meaningful_words = [w for w in words if not w in stops]   
    # 6. Save only noun
    meaningful_words = pos_tag(meaningful_words)
    meaningful_words = [word for word,pos in meaningful_words if pos == 'NNS']
    # 7. Join the words back into one string separated by space, 
    # and return the result.
    return( " ".join( meaningful_words ))

# %%
from bs4 import BeautifulSoup        
clean_review = review_to_words( train["Review"][0] )
# Out:
# /usr/local/lib/python3.4/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /usr/lib/python3.4/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
# Get the number of reviews based on the dataframe column size
num_reviews = train["Review"].size

# Initialize an empty list to hold the clean reviews
clean_train_reviews = []

# Loop over each review; create an index i that goes from 0 to the length
# of the review list 
for i in range( 0, num_reviews ):
    # Call our function for each one, and add the result to the list of
    # clean reviews
    clean_train_reviews.append( review_to_words( train["Review"][i] ) )
# Out:
# /usr/local/lib/python3.4/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /usr/lib/python3.4/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
print ("Cleaning and parsing the training set reviews...\n")
clean_train_reviews = []
for i in range( 0, num_reviews ):
    # If the index is evenly divisible by 1000, print a message
    if( (i+1)%1000 == 0 ):
        print ("Review %d of %d\n" % ( i+1, num_reviews ) )                                                                   
    clean_train_reviews.append( review_to_words( train["Review"][i] ))
# Out:
# Cleaning and parsing the training set reviews...
# /usr/local/lib/python3.4/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /usr/lib/python3.4/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Review 1000 of 1167

# %%
print ("Creating the bag of words...\n")
from sklearn.feature_extraction.text import CountVectorizer

# Initialize the "CountVectorizer" object, which is scikit-learn's
# bag of words tool.  
vectorizer = CountVectorizer(analyzer = "word",   \
                             tokenizer = None,    \
                             preprocessor = None, \
                             stop_words = None,   \
                             max_features = 5000) 

# fit_transform() does two functions: First, it fits the model
# and learns the vocabulary; second, it transforms our training data
# into feature vectors. The input to fit_transform should be a list of 
# strings.
train_data_features = vectorizer.fit_transform(clean_train_reviews)

# Numpy arrays are easy to work with, so convert the result to an 
# array
train_data_features = train_data_features.toarray()
# Out:
# Creating the bag of words...

# %%
 train_data_features.shape
# Out:
# (1167, 5000)

# %%
# Take a look at the words in the vocabulary
vocab = vectorizer.get_feature_names()
print (vocab[:20])
# Out:
# ['abends', 'abilities', 'abordables', 'abraham', 'accents', 'accepts', 'accessories', 'accidents', 'accolades', 'accommodations', 'accompanies', 'accompaniments', 'accomplishments', 'accounts', 'accoutrements', 'accusations', 'aces', 'achari', 'aches', 'acoustics']

# %%
import numpy as np

# Sum up the counts of each vocabulary word
dist = np.sum(train_data_features, axis=0)

# For each, print the vocabulary word and the number of times it 
# appears in the training set
for tag, count in zip(vocab, dist):
    print (count, tag)
# Out:
# 2 abends
# 2 abilities
# 4 abordables
# 2 abraham
# 17 accents
# 6 accepts
# 39 accessories
# 4 accidents
# 5 accolades
# 13 accommodations
# 5 accompanies
# 25 accompaniments
# 2 accomplishments
# 9 accounts
# 4 accoutrements
# 3 accusations
# 6 aces
# 2 achari
# 4 aches
# 22 acoustics
# 4 acquaintances
# 2 acres
# 2 acrylics
# 10 actions
# 30 activities
# 12 actors
# 24 acts
# 9 adams
# 4 add
# 2 addictions
# 4 addicts
# 14 additions
# 4 additives
# 4 addresses
# 5 adjectives
# 15 adjustments
# 2 administers
# 3 admissions
# 2 adopt
# 2 adopters
# 6 ads
# 104 adults
# 2 advantages
# 9 adventures
# 4 advertisements
# 5 advertises
# 4 aerobics
# 7 aesthetics
# 4 affairs
# 2 affects
# 20 afternoons
# 100 afterwards
# 2 afterwords
# 6 agents
# 55 ages
# 3 agnolotti
# 2 ahi
# 7 aids
# 2 ailleurs
# 4 aioli
# 5 airlines
# 56 aisles
# 2 aka
# 2 al
# 31 alas
# 2 albeit
# 2 albertsons
# 9 ales
# 2 alfajores
# 4 alfredo
# 2 alimentaires
# 3 aliments
# 3 allerdings
# 2 allergens
# 44 allergies
# 18 alles
# 2 allies
# 10 allows
# 2 alls
# 57 almonds
# 8 aloo
# 10 alors
# 16 als
# 71 alterations
# 30 alternatives
# 2 alters
# 2 alumni
# 2 amateurs
# 5 amazeballs
# 2 amels
# 4 amen
# 2 amendes
# 66 amenities
# 6 america
# 2 americana
# 52 americans
# 61 amounts
# 4 anchors
# 22 anchovies
# 3 anderen
# 2 andy
# 43 angeles
# 14 angels
# 6 angles
# 105 animals
# 2 ann
# 4 anniversaries
# 3 annoyances
# 2 annoys
# 2 annuals
# 10 ans
# 34 answers
# 4 anti
# 8 antibiotics
# 5 antiques
# 4 ants
# 2 anyones
# 121 anyways
# 2 anywhere
# 2 aoli
# 6 apartmentratings
# 22 apartments
# 29 apologies
# 4 apologize
# 6 app
# 2 apparences
# 7 appeals
# 8 appearances
# 6 appetisers
# 2 appetite
# 17 appetites
# 4 appetizer
# 787 appetizers
# 10 appitizers
# 4 applebee
# 6 applebees
# 51 apples
# 8 appliances
# 4 applications
# 26 applies
# 67 appointments
# 2 approaches
# 12 apps
# 5 appts
# 3 apricots
# 3 aprons
# 2 apts
# 133 areas
# 2 arena
# 2 argue
# 3 arguments
# 2 arises
# 7 arizona
# 2 armands
# 2 armchairs
# 2 armpits
# 31 arms
# 3 aroma
# 11 aromas
# 8 aromatics
# 2 arrabiata
# 32 arrangements
# 4 arrivals
# 19 arrives
# 2 arrows
# 7 arteries
# 3 arthurs
# 18 artichokes
# 7 articles
# 5 artifacts
# 25 artists
# 36 arts
# 2 ashes
# 9 asians
# 2 asiatiques
# 20 ask
# 7 asked
# 17 asks
# 2 asparagus
# 26 aspects
# 7 asses
# 8 assistants
# 40 associates
# 2 assumptions
# 3 atkins
# 6 atm
# 3 atmospheres
# 12 atria
# 2 attachments
# 26 attempts
# 17 attendants
# 10 attendees
# 17 attitudes
# 19 attractions
# 2 attracts
# 4 attributes
# 4 aubergines
# 3 audiences
# 3 aunties
# 6 aunts
# 2 authentiques
# 2 authorities
# 2 authors
# 4 automobiles
# 9 autres
# 5 averages
# 2 avets
# 6 avions
# 3 avocado
# 5 avoid
# 3 avoids
# 31 avons
# 2 awaits
# 29 awards
# 10 aways
# 4 az
# 31 babies
# 2 baby
# 2 bachelors
# 2 backgrounds
# 2 backpacks
# 13 backs
# 17 backwards
# 2 backwoods
# 5 bacon
# 2 bacons
# 3 bacteria
# 7 bag
# 6 bagel
# 96 bagels
# 59 bags
# 5 baguettes
# 5 baileys
# 42 bakeries
# 5 bakers
# 4 bakes
# 2 baklava
# 2 balances
# 4 balconies
# 2 ballads
# 6 balloons
# 2 ballparks
# 4 ballrooms
# 204 balls
# 21 banana
# 17 bananas
# 36 bands
# 2 bang
# 3 bangers
# 2 bangles
# 22 bangs
# 4 bankers
# 12 banks
# 2 banners
# 2 banquets
# 6 bar
# 2 barbecues
# 15 barbers
# 2 barebones
# 4 bargains
# 34 baristas
# 23 barnes
# 7 barrels
# 2 barren
# 240 bars
# 2 barstools
# 196 bartenders
# 10 bases
# 58 basics
# 3 basil
# 4 basils
# 38 baskets
# 15 basmati
# 5 bastards
# 4 batata
# 13 batches
# 2 bates
# 128 bathrooms
# 2 baths
# 7 batteries
# 2 battles
# 6 battleships
# 3 bawarchi
# 2 bay
# 2 bays
# 2 bbb
# 7 bbq
# 4 bc
# 6 beads
# 5 beams
# 397 beans
# 2 beards
# 3 bearings
# 4 bears
# 2 beaters
# 37 beats
# 2 beautiful
# 15 becomes
# 2 bedbugs
# 85 beds
# 3 bedsheets
# 2 bedspreads
# 637 beers
# 8 bees
# 28 beets
# 2 beg
# 3 begin
# 7 beginners
# 7 beginnings
# 4 begins
# 2 behaves
# 4 behaviors
# 10 beings
# 2 belgians
# 2 beliefs
# 10 believe
# 2 bellevue
# 16 bellies
# 9 bells
# 3 bellydancers
# 13 belongings
# 9 belongs
# 3 belts
# 18 benches
# 2 bends
# 3 benedicts
# 18 benefits
# 2 benjamins
# 2 bens
# 2 bereits
# 26 berries
# 13 besides
# 4 besonders
# 2 besties
# 5 beth
# 9 betos
# 9 bets
# 107 beverages
# 9 bf
# 3 bhaji
# 2 bharta
# 2 biceps
# 9 bicycles
# 3 bids
# 4 bikers
# 39 bikes
# 2 billboards
# 2 billiards
# 64 bills
# 11 bins
# 16 birds
# 3 biriyani
# 20 birthdays
# 2 births
# 31 biryani
# 3 biryanis
# 14 biscotti
# 44 biscuits
# 5 bishops
# 3 bit
# 4 bitches
# 3 bite
# 188 bites
# 100 bits
# 5 bitters
# 2 bizarre
# 3 blackberries
# 3 blacks
# 5 blades
# 4 blah
# 13 blankets
# 3 blasts
# 7 blazers
# 2 bleachers
# 3 blemishes
# 18 blends
# 2 blessings
# 2 blew
# 11 blinds
# 3 blizzards
# 2 blob
# 138 blocks
# 4 blogs
# 3 blonde
# 3 blossoms
# 4 blouses
# 2 blowouts
# 9 blows
# 3 blts
# 21 blueberries
# 60 blues
# 2 blumengarten
# 3 boar
# 16 boards
# 3 boars
# 10 boasts
# 6 boats
# 6 bobcats
# 5 bodies
# 2 boggles
# 8 bojangles
# 3 bok
# 4 bolts
# 2 bomb
# 10 bombay
# 2 bombers
# 3 bombs
# 3 bonds
# 103 bones
# 3 bonnes
# 13 bons
# 3 bonus
# 2 bonuses
# 2 boofays
# 3 bookmarks
# 128 books
# 5 bookstores
# 2 boomers
# 3 boonies
# 5 booth
# 2 boothes
# 145 booths
# 3 booties
# 26 boots
# 7 borders
# 2 bores
# 2 borics
# 5 born
# 4 bosses
# 2 bother
# 15 bothers
# 12 bottle
# 150 bottles
# 6 bottoms
# 5 bouncers
# 2 boundaries
# 6 bounds
# 9 bouquets
# 5 boutiques
# 2 boutonnieres
# 2 bowels
# 5 bowl
# 13 bowls
# 4 bows
# 7 box
# 5 boxers
# 110 boxes
# 4 boy
# 12 boyfriends
# 38 boys
# 4 braces
# 2 brags
# 3 braids
# 2 brains
# 29 brakes
# 9 branches
# 2 brandon
# 51 brands
# 2 bras
# 11 brats
# 4 bread
# 6 breadcrumbs
# 177 breads
# 49 breadsticks
# 16 breadworks
# 38 breakfasts
# 26 breaks
# 12 breasts
# 3 breaths
# 3 breeds
# 2 brethren
# 6 breweries
# 2 brewers
# 69 brews
# 2 bricks
# 10 brides
# 33 bridesmaids
# 5 bridges
# 2 brigens
# 42 brings
# 3 brits
# 2 brixx
# 19 broccoli
# 3 brochures
# 48 bros
# 69 brothers
# 2 broths
# 16 brownies
# 52 browns
# 4 brows
# 3 browse
# 14 brueggers
# 2 bruggers
# 2 bruises
# 2 brunch
# 14 brunches
# 4 bruschetta
# 8 brushes
# 4 brussels
# 12 bubbles
# 19 buckets
# 316 bucks
# 23 buddies
# 4 budgets
# 78 buds
# 3 budweisers
# 3 buffalo
# 187 buffet
# 559 buffets
# 31 bugs
# 2 builders
# 43 buildings
# 4 bulbs
# 3 bulldogs
# 3 bullets
# 4 bulls
# 7 bumps
# 4 bums
# 5 bun
# 53 buns
# 2 burger
# 528 burgers
# 4 burgh
# 3 burghers
# 10 burners
# 5 burns
# 12 burnt
# 6 burrito
# 24 burritos
# 3 bursts
# 2 busers
# 10 buses
# 2 bushes
# 2 bushings
# 98 businesses
# 5 businessmen
# 2 buslines
# 9 bussers
# 32 busters
# 4 butchers
# 2 butt
# 5 butterflies
# 7 butters
# 15 buttons
# 8 buyers
# 9 buys
# 2 buzzers
# 2 byo
# 4 byob
# 3 cab
# 2 cabinets
# 2 cables
# 2 cabs
# 4 caesar
# 4 caesars
# 2 caf
# 6 cafe
# 34 cafeteria
# 6 cages
# 9 cains
# 5 cajun
# 2 cake
# 397 cakes
# 2 calabria
# 16 calamari
# 2 calculations
# 6 calendars
# 4 california
# 32 calls
# 2 calm
# 74 calories
# 29 calzones
# 2 camel
# 2 camels
# 11 cameras
# 2 campbells
# 8 camps
# 2 campus
# 3 canadians
# 2 cancellations
# 17 candies
# 51 candles
# 4 canisters
# 8 cannoli
# 3 cannolis
# 52 cannot
# 23 cans
# 2 capabilities
# 21 capers
# 3 capitals
# 13 caps
# 2 captains
# 3 caramel
# 7 caramels
# 16 carbs
# 3 cardamom
# 2 cardholders
# 8 cardinals
# 259 cards
# 74 cares
# 10 carhops
# 4 carmen
# 12 carnitas
# 22 carnivores
# 16 carolina
# 2 carottes
# 3 carowinds
# 12 carpets
# 3 carriages
# 5 carriers
# 17 carrot
# 102 carrots
# 142 cars
# 6 carte
# 2 cartons
# 30 carts
# 2 carvings
# 65 cases
# 37 cashews
# 47 cashiers
# 4 casings
# 5 casinos
# 2 casseroles
# 2 castles
# 2 casts
# 3 casual
# 7 cat
# 10 categories
# 8 caterers
# 28 caters
# 67 cats
# 5 cattle
# 2 caucasians
# 3 cauliflowers
# 5 causes
# 3 caveats
# 7 cavities
# 3 cds
# 2 cees
# 52 ceilings
# 9 celebrations
# 8 celebrities
# 3 cello
# 3 cellphones
# 3 celtics
# 9 centerpieces
# 20 centers
# 3 centre
# 82 cents
# 4 ceramics
# 3 cereals
# 2 certaines
# 3 certains
# 7 certificates
# 10 ces
# 7 chaat
# 19 chaats
# 15 chai
# 64 chains
# 255 chairs
# 2 chaises
# 8 challenges
# 16 champions
# 3 championships
# 10 champs
# 14 chana
# 44 chances
# 33 chandeliers
# 2 chang
# 178 changes
# 26 changs
# 5 channel
# 16 channels
# 8 chapati
# 3 char
# 4 characteristics
# 18 characters
# 3 chargers
# 83 charges
# 7 charles
# 16 charlotte
# 2 charlotteans
# 8 charts
# 16 chat
# 20 chats
# 64 cheap
# 2 cheats
# 13 check
# 2 checked
# 7 checkers
# 5 checkouts
# 91 checks
# 5 cheeks
# 2 cheerleaders
# 66 cheers
# 54 cheese
# 7 cheeseburgers
# 8 cheesecakes
# 123 cheeses
# 4 cheesesteaks
# 3 cheesy
# 8 chef
# 69 chefs
# 12 chemicals
# 12 cherries
# 2 chers
# 6 cherubs
# 4 chestnuts
# 2 chews
# 19 chewy
# 5 chi
# 13 chicago
# 3 chiches
# 62 chicken
# 8 chickens
# 3 chickpea
# 83 chickpeas
# 8 chicks
# 252 children
# 4 childrens
# 4 childs
# 16 chiles
# 28 chili
# 19 chilies
# 3 chilis
# 11 chilli
# 2 chillie
# 15 chillies
# 6 chills
# 6 china
# 7 chinese
# 2 chipati
# 370 chips
# 8 chiropractors
# 5 chives
# 26 chocolates
# 691 choices
# 22 cholas
# 3 choose
# 2 chooses
# 94 chops
# 12 chopsticks
# 2 chores
# 2 chorizo
# 3 chosen
# 4 chris
# 20 christmas
# 14 christos
# 2 chubbies
# 2 chuckles
# 6 chucks
# 269 chunks
# 2 chunky
# 6 churches
# 2 churros
# 2 chutney
# 244 chutneys
# 5 chutnies
# 7 ciders
# 19 cigarettes
# 22 cigars
# 7 cilantro
# 3 cincinnati
# 3 cinnamon
# 14 circles
# 2 circuits
# 22 circumstances
# 102 cities
# 13 citizens
# 32 claims
# 2 clam
# 40 clams
# 87 classes
# 36 classics
# 3 classiques
# 2 classmates
# 4 classy
# 7 clean
# 54 cleaners
# 4 cleanings
# 3 cleans
# 5 clerks
# 4 clicks
# 23 clientele
# 75 clients
# 7 clinics
# 3 clippers
# 5 clippings
# 5 clips
# 4 clocks
# 5 closer
# 31 closes
# 3 closets
# 2 closings
# 2 cloth
# 253 clothes
# 27 cloths
# 11 cloves
# 5 clowns
# 2 clubbers
# 22 clubs
# 6 clues
# 2 clumps
# 3 clusters
# 2 cm
# 3 cmc
# 5 coaches
# 4 coasts
# 2 coatings
# 22 coats
# 2 cobblers
# 2 cobra
# 12 cockroaches
# 200 cocktails
# 4 coconut
# 3 cod
# 8 codes
# 2 coffee
# 56 coffees
# 2 coin
# 11 cokes
# 2 coleslaw
# 2 coli
# 9 collards
# 60 colleagues
# 2 collectibles
# 3 collections
# 4 collins
# 104 colors
# 7 colours
# 3 colts
# 45 combinations
# 6 combines
# 2 combo
# 20 combos
# 5 come
# 19 comedians
# 4 comers
# 2 comforters
# 4 comforts
# 4 comfy
# 9 comics
# 3 commandes
# 2 commentaires
# 2 commentators
# 98 comments
# 7 commercials
# 3 commons
# 2 communities
# 3 compadres
# 35 companies
# 52 companions
# 7 compares
# 7 comparisons
# 5 compartments
# 2 compatriots
# 2 compels
# 4 compensates
# 3 competes
# 32 competitors
# 3 complainers
# 7 complains
# 263 complaints
# 11 complements
# 4 completes
# 2 complexities
# 6 complications
# 77 compliments
# 26 components
# 13 computers
# 2 comrades
# 7 concepts
# 56 concerns
# 7 concerts
# 6 concessions
# 3 conclusions
# 7 concoctions
# 73 condiments
# 3 conditioners
# 19 conditions
# 24 cones
# 5 confections
# 2 conferees
# 4 conferences
# 2 confines
# 2 confirmations
# 2 confirms
# 2 conflicts
# 2 congo
# 5 congrats
# 8 congratulations
# 3 connections
# 5 connoisseurs
# 154 cons
# 2 consequences
# 3 considerations
# 5 considers
# 2 consistencies
# 2 consoles
# 2 consonants
# 6 constraints
# 2 constructions
# 7 consultants
# 3 consults
# 9 consumers
# 15 contacts
# 2 container
# 81 containers
# 15 contains
# 3 contenders
# 19 contents
# 4 contests
# 6 continents
# 3 continue
# 2 contractions
# 6 contractors
# 4 contracts
# 2 contributions
# 3 controls
# 4 conveniences
# 11 conventions
# 51 conversations
# 2 conveys
# 4 cook
# 3 cookbooks
# 13 cooked
# 2 cookie
# 262 cookies
# 84 cooks
# 6 cool
# 12 coolers
# 4 cools
# 11 coors
# 2 copes
# 3 copies
# 11 cops
# 2 cor
# 2 cores
# 2 corndogs
# 10 corner
# 41 corners
# 2 corona
# 3 corporations
# 3 corrects
# 3 corridors
# 2 corsages
# 2 cos
# 4 cosmetics
# 2 cosmetologists
# 3 cosmo
# 9 cosmos
# 3 costco
# 150 costs
# 3 costumers
# 6 costumes
# 3 cosy
# 38 couches
# 2 cougars
# 2 couldnt
# 6 counterparts
# 15 counters
# 28 countries
# 2 countrymen
# 17 counts
# 2 couple
# 73 couples
# 132 coupons
# 193 courses
# 2 courtesy
# 11 courts
# 4 cousins
# 2 coverings
# 27 covers
# 2 cowboys
# 107 coworkers
# 2 cows
# 20 cozy
# 30 crab
# 7 crabcakes
# 3 crabs
# 30 crackers
# 3 crackheads
# 6 cracks
# 2 craft
# 4 crafters
# 22 crafts
# 3 craftsmen
# 2 craig
# 3 cramped
# 4 cramps
# 9 cranberries
# 4 crannies
# 3 crates
# 4 craves
# 58 cravings
# 9 crayons
# 3 creamers
# 19 creams
# 51 creamy
# 9 creates
# 21 creations
# 4 creatures
# 4 credentials
# 10 credits
# 6 creepy
# 12 crepe
# 59 crepes
# 3 crevettes
# 3 crevices
# 4 crews
# 2 cries
# 11 crisp
# 3 crispies
# 20 crispy
# 2 criteria
# 9 criticisms
# 6 critics
# 4 critiques
# 2 critters
# 10 croissants
# 5 croquettes
# 2 cross
# 26 croutons
# 36 crowd
# 4 crowds
# 3 crowns
# 3 cruellers
# 5 crumbles
# 16 crumbs
# 2 crushes
# 9 crusts
# 2 crusty
# 14 crystals
# 2 cubed
# 85 cubes
# 4 cubs
# 36 cucumbers
# 5 cues
# 47 cuisines
# 2 cuits
# 2 cukes
# 9 cultures
# 16 cup
# 46 cupcakes
# 167 cups
# 2 curators
# 2 curd
# 6 curds
# 2 cures
# 2 curies
# 16 curls
# 706 curries
# 4 curry
# 20 curtains
# 18 cushions
# 992 customers
# 2 customizations
# 3 cut
# 6 cuticles
# 7 cutlets
# 163 cuts
# 6 cutters
# 2 cuz
# 2 cycles
# 2 cyclists
# 3 daal
# 6 daals
# 8 dad
# 2 daddies
# 9 dads
# 2 daggers
# 2 daisies
# 2 dal
# 14 dallas
# 9 dals
# 5 damages
# 4 damn
# 26 dancers
# 20 dances
# 5 dangers
# 9 daniels
# 6 danishes
# 87 dans
# 3 dare
# 11 darren
# 12 darts
# 39 das
# 4 data
# 48 dates
# 24 daughters
# 1137 days
# 3 dc
# 2 deadlines
# 6 dealers
# 5 dealerships
# 151 deals
# 2 deans
# 49 decades
# 5 decemberists
# 2 decibels
# 6 decides
# 18 decisions
# 5 decor
# 103 decorations
# 6 decorators
# 3 decors
# 4 def
# 2 deficiencies
# 3 defines
# 40 degrees
# 2 dehors
# 17 delays
# 8 delhi
# 5 deli
# 23 delicacies
# 11 delicious
# 27 delights
# 2 delis
# 18 deliveries
# 41 delivers
# 5 demands
# 3 demographics
# 8 demonstrations
# 2 denny
# 6 dentists
# 4 dents
# 11 departments
# 9 depends
# 2 dept
# 4 depths
# 100 des
# 4 describe
# 7 describes
# 54 descriptions
# 69 deserts
# 52 deserves
# 6 desi
# 15 designers
# 12 designs
# 5 desires
# 5 desks
# 4 dessert
# 485 desserts
# 7 destinations
# 2 destroyers
# 102 details
# 3 detroit
# 2 developers
# 5 developments
# 2 deviations
# 11 devices
# 9 dhaba
# 2 diabetes
# 6 diabetics
# 2 diagnoses
# 6 diamonds
# 2 dice
# 2 dicks
# 10 didnt
# 4 die
# 2 dients
# 2 diet
# 2 dieters
# 10 diets
# 21 differences
# 3 differs
# 13 difficulties
# 3 digits
# 4 digs
# 2 diiorios
# 2 dijon
# 5 dillards
# 2 dim
# 5 dimensions
# 2 dimes
# 3 din
# 231 diners
# 5 dines
# 3 dings
# 22 dinner
# 159 dinners
# 2 dip
# 2 dippers
# 2 dippings
# 74 dips
# 45 directions
# 3 disappears
# 7 disappointments
# 37 disappoints
# 4 disasters
# 2 disclaimers
# 45 discounts
# 2 discoveries
# 6 discussions
# 3 dish
# 4057 dishes
# 6 dislikes
# 2 dismay
# 4 disons
# 5 dispensers
# 29 displays
# 3 distinguishes
# 4 distributors
# 31 dives
# 2 divisions
# 3 docents
# 3 docks
# 29 doctors
# 9 documents
# 3 doesnt
# 3 dog
# 482 dogs
# 318 dollars
# 2 dollops
# 3 dolls
# 12 domestics
# 7 dominos
# 2 donatelli
# 4 donations
# 9 dont
# 3 donut
# 79 donuts
# 2 doormen
# 164 doors
# 2 dora
# 3 doritos
# 18 dosa
# 8 dosai
# 28 dosas
# 7 doses
# 8 doubles
# 11 doubts
# 19 doughnuts
# 4 doughy
# 2 doves
# 2 downers
# 6 downs
# 15 downsides
# 95 downstairs
# 33 dozens
# 3 dr
# 2 draft
# 46 drafts
# 2 drains
# 12 drapes
# 11 drawbacks
# 3 drawers
# 6 drawings
# 3 draws
# 20 dreams
# 2 dreds
# 2 dressers
# 92 dresses
# 30 dressings
# 5 driers
# 2 dries
# 2 drills
# 7 drink
# 19 drinkers
# 1707 drinks
# 3 drips
# 26 drivers
# 12 drives
# 2 droplets
# 4 droppings
# 12 drops
# 2 droves
# 9 drugs
# 9 drums
# 7 drumsticks
# 13 drunks
# 18 dry
# 31 dryers
# 2 ducks
# 18 dudes
# 2 duds
# 3 duh
# 8 dukes
# 2 dumbbells
# 144 dumplings
# 3 dumps
# 6 dunnings
# 8 duties
# 2 dwellers
# 2 dyes
# 3 eagle
# 18 eagles
# 3 earns
# 12 earrings
# 17 ears
# 2 eat
# 25 eaten
# 43 eateries
# 91 eaters
# 105 eats
# 3 echoes
# 3 economics
# 62 edges
# 5 edinburgh
# 12 effects
# 16 efforts
# 5 eggplants
# 7 eggrolls
# 300 eggs
# 2 egos
# 3 eh
# 2 eines
# 4 elbows
# 3 elders
# 15 electronics
# 31 elements
# 6 elephants
# 20 elevators
# 5 ellipticals
# 17 emails
# 3 embers
# 3 embodies
# 2 emils
# 13 emissions
# 4 emotions
# 7 empanadas
# 497 employees
# 3 employers
# 9 empty
# 2 enclaves
# 2 encompasses
# 5 encounters
# 2 encourages
# 4 endeavors
# 2 endings
# 2 endroits
# 28 ends
# 2 enfants
# 2 engineers
# 2 enhances
# 3 enjoy
# 2 ensues
# 2 ensures
# 2 enterprises
# 3 enters
# 3 entertainers
# 2 entices
# 3 entr
# 9 entrances
# 3 entree
# 828 entrees
# 6 entres
# 11 entries
# 4 envelopes
# 2 environments
# 5 environs
# 23 eons
# 7 equals
# 15 errands
# 7 errors
# 11 ers
# 7 escalators
# 6 espresso
# 13 essentials
# 98 establishments
# 7 estimates
# 2 et
# 6 etc
# 12 ethics
# 2 europeans
# 4 evans
# 54 evenings
# 174 events
# 5 everyones
# 2 everythings
# 14 examples
# 2 exceeds
# 3 excellents
# 3 excels
# 8 exceptions
# 4 excites
# 2 excursions
# 21 excuses
# 2 executives
# 2 exemplifies
# 5 exercises
# 2 exhibitions
# 42 exhibits
# 13 exists
# 362 expectations
# 4 expenses
# 297 experiences
# 5 experiments
# 14 experts
# 7 explains
# 9 explanations
# 3 explodes
# 6 explosions
# 6 expressions
# 18 extensions
# 3 extra
# 23 extras
# 2 extremes
# 4 exudes
# 15 eyebrows
# 185 eyes
# 3 fabrics
# 3 facets
# 9 facials
# 44 facilities
# 4 factories
# 11 factors
# 10 facts
# 2 fades
# 2 fails
# 2 fajita
# 13 fajitas
# 2 falafel
# 6 falls
# 2 falters
# 2 famers
# 5 famiglia
# 2 familes
# 128 families
# 3 fanatics
# 145 fans
# 3 fantasies
# 3 fares
# 14 farmers
# 4 farms
# 2 fashions
# 3 fast
# 2 fathers
# 7 fats
# 3 faucets
# 3 faults
# 2 fav
# 24 faves
# 6 favorite
# 251 favorites
# 26 favors
# 2 favourite
# 12 favourites
# 6 fears
# 4 feasts
# 4 feathers
# 65 features
# 3 feces
# 14 feeds
# 38 feel
# 40 feelings
# 227 feels
# 44 fees
# 123 feet
# 2 fellas
# 5 fellows
# 121 felt
# 11 females
# 3 fennel
# 9 feria
# 9 festivals
# 8 festivities
# 3 fianc
# 6 fiances
# 15 fields
# 2 fiends
# 5 fifth
# 7 fights
# 6 figs
# 3 figues
# 8 figures
# 3 figurines
# 4 files
# 16 filets
# 2 filibertos
# 5 fillers
# 7 fillets
# 41 fillings
# 39 fills
# 6 filmmakers
# 17 films
# 4 finals
# 2 finances
# 15 find
# 2 findings
# 14 finds
# 2 fingernails
# 4 fingerprints
# 96 fingers
# 2 fingertips
# 16 finishes
# 2 fiori
# 2 firearms
# 13 fires
# 10 fireworks
# 2 fishcakes
# 3 fishes
# 5 fishy
# 43 fits
# 5 fittings
# 16 fix
# 8 fixes
# 23 fixings
# 5 fixins
# 22 fixtures
# 5 flags
# 37 flakes
# 6 flaky
# 2 flamingo
# 2 flapjacks
# 2 flash
# 2 flashes
# 2 flashlights
# 7 flatbreads
# 9 flatmates
# 5 flats
# 7 flavorful
# 3 flavorings
# 1087 flavors
# 6 flavour
# 54 flavours
# 7 flaws
# 5 flecks
# 2 flemings
# 2 fliers
# 33 flies
# 15 flights
# 2 flintstones
# 3 flips
# 2 flirtations
# 10 floats
# 124 floors
# 9 flops
# 3 florals
# 5 florets
# 4 florists
# 17 flour
# 2 flourets
# 2 flours
# 177 flowers
# 33 fluffy
# 9 fluids
# 3 fluke
# 3 flushes
# 2 fly
# 2 flyers
# 2 foccacia
# 2 focuses
# 10 foils
# 344 folks
# 2 followers
# 4 foodie
# 29 foodies
# 775 foods
# 4 foodstuffs
# 5 fools
# 2 footbeds
# 4 forbes
# 4 forces
# 4 foreigners
# 4 forget
# 16 forgot
# 5 forgotten
# 34 forks
# 10 forms
# 2 fortune
# 7 fortunes
# 2 forums
# 3 founders
# 5 fountains
# 5 fragrances
# 8 frames
# 2 franchisees
# 2 francisco
# 8 franks
# 6 freaks
# 6 freebies
# 3 freezers
# 2 frequenters
# 9 frequents
# 6 fresh
# 5 fresheners
# 34 fridays
# 4 fridges
# 1583 friends
# 1714 fries
# 77 frills
# 5 frites
# 2 frittata
# 75 fritters
# 3 fronts
# 2 frowns
# 20 frozen
# 59 fruits
# 3 frustrations
# 2 frutti
# 2 fry
# 2 fryers
# 3 fuelperks
# 3 fuels
# 5 fumes
# 4 fun
# 10 functions
# 2 fundamentals
# 5 fundraisers
# 11 funds
# 2 funky
# 3 funnel
# 25 furnishings
# 2 fusilli
# 4 fyi
# 7 gadgets
# 2 gags
# 3 gains
# 4 galleria
# 7 galleries
# 7 gallons
# 10 gals
# 286 games
# 6 gandhi
# 4 ganges
# 12 garages
# 12 gardens
# 2 garlicky
# 12 garments
# 2 garmets
# 7 garnishes
# 2 gars
# 5 gates
# 14 gatherings
# 2 gay
# 2 gaylords
# 2 gears
# 3 gelatos
# 2 gels
# 2 gem
# 29 gems
# 2 generates
# 15 generations
# 3 generics
# 3 genes
# 4 genres
# 2 gentleman
# 38 gentlemen
# 5 gents
# 3 germans
# 4 germs
# 8 gestures
# 30 get
# 6 gf
# 3 ghandi
# 2 ghee
# 4 giants
# 2 giftcards
# 58 gifts
# 2 giggles
# 8 gills
# 7 gimmicks
# 22 girl
# 35 girlfriends
# 201 girls
# 36 glad
# 3 glances
# 2 glares
# 336 glasses
# 2 glaze
# 2 glitches
# 2 globes
# 3 glories
# 22 gloves
# 53 gluten
# 2 gnats
# 40 gnocchi
# 33 go
# 3 goals
# 3 goat
# 6 goats
# 8 gobi
# 9 goblets
# 3 gobs
# 10 god
# 20 gods
# 18 goers
# 2 goggles
# 3 goldilocks
# 10 gonna
# 2 goodbye
# 79 goodies
# 185 goods
# 2 gooey
# 2 gosh
# 17 got
# 24 gotta
# 41 gotten
# 4 gowns
# 17 grab
# 3 grabbed
# 9 graces
# 4 grades
# 2 graduates
# 20 grains
# 3 grams
# 2 grandkids
# 2 grandma
# 9 grandmothers
# 17 grandparents
# 3 grandsons
# 2 grants
# 3 granules
# 2 grapefruits
# 10 grapes
# 31 gras
# 4 graves
# 23 gravies
# 6 gravy
# 10 greasy
# 3 greats
# 3 greenbacks
# 2 greenhouses
# 152 greens
# 4 greet
# 3 greeters
# 2 greetings
# 18 greets
# 2 gremlins
# 5 grill
# 2 grille
# 13 grills
# 5 grinders
# 4 grinds
# 2 gringos
# 2 grins
# 2 gripe
# 8 gripes
# 92 grits
# 2 gritty
# 7 groceria
# 133 groceries
# 14 grocers
# 7 groomers
# 2 grosses
# 29 grounds
# 24 groupon
# 29 groupons
# 210 groups
# 2 growers
# 6 growlers
# 7 grows
# 5 grub
# 2 grubhub
# 2 grudges
# 3 grunts
# 3 guarantees
# 13 guards
# 4 guesses
# 254 guests
# 2 guidebooks
# 6 guidelines
# 8 guides
# 3 guitars
# 2 gujarati
# 11 gumes
# 2 gummies
# 8 gums
# 18 guns
# 3 gurkha
# 2 gustatives
# 3 gut
# 3 gutes
# 11 guts
# 7 guy
# 551 guys
# 12 gym
# 3 gyms
# 8 gyro
# 40 gyros
# 4 ha
# 2 habaneros
# 8 habits
# 2 hacks
# 6 haircut
# 48 haircuts
# 7 hairdressers
# 12 hairs
# 2 hairstyles
# 10 halls
# 16 hallways
# 9 halves
# 4 halwa
# 3 ham
# 23 hamburgers
# 2 hamsters
# 8 handbags
# 2 handi
# 3 handle
# 6 handles
# 4 handrolls
# 417 hands
# 2 hang
# 7 hangers
# 6 hangings
# 2 hangouts
# 2 hangovers
# 11 hangs
# 7 happen
# 4 happenings
# 21 happens
# 2 hard
# 2 hards
# 3 harris
# 3 hartigans
# 7 hashbrowns
# 5 hassle
# 4 hassles
# 12 haters
# 9 hates
# 27 hats
# 10 haunts
# 3 hawkins
# 6 haywards
# 3 hazards
# 2 hazelnuts
# 2 hd
# 7 headaches
# 4 headlights
# 10 headphones
# 67 heads
# 3 heaps
# 2 hear
# 23 hearts
# 6 heaters
# 4 heavens
# 3 heavy
# 19 heels
# 16 heights
# 6 hello
# 2 helmets
# 2 help
# 6 helpers
# 3 helpful
# 8 helpings
# 7 helps
# 2 hems
# 2 hendricks
# 26 herbs
# 9 heres
# 5 heroes
# 5 herpes
# 2 hes
# 8 hey
# 3 hibachi
# 6 hiccups
# 2 hiers
# 113 highlights
# 5 highs
# 2 hightops
# 3 highways
# 2 hikes
# 2 hillbillies
# 101 hills
# 3 hines
# 3 hinges
# 2 hings
# 14 hints
# 4 hippies
# 6 hips
# 34 hipsters
# 4 hit
# 67 hits
# 2 hives
# 2 hmm
# 2 hmmmm
# 4 hoagie
# 135 hoagies
# 2 hobbies
# 2 hoggies
# 19 holders
# 38 holes
# 57 holidays
# 9 holmes
# 32 homefries
# 21 homes
# 2 homey
# 2 honks
# 2 hoodies
# 3 hookers
# 2 hooks
# 12 hooters
# 74 hopes
# 2 horchata
# 7 horizons
# 2 hormones
# 2 hornets
# 5 horns
# 6 hors
# 14 horses
# 7 hospitals
# 11 hostesses
# 26 hosts
# 23 hot
# 114 hotcakes
# 27 hotdogs
# 119 hotels
# 2 houlihans
# 1049 hours
# 2 households
# 50 houses
# 7 housewares
# 2 hr
# 3 hrs
# 2 hubbies
# 2 hubby
# 10 hubs
# 2 hues
# 2 hug
# 3 hugs
# 8 humans
# 2 hummes
# 4 hummus
# 3 humps
# 47 hundreds
# 14 hunks
# 2 hurdles
# 2 hurt
# 7 hurts
# 2 husband
# 19 husbands
# 14 hushpuppies
# 2 huts
# 2 hygienists
# 2 icees
# 2 id
# 2 ideals
# 33 ideas
# 12 idiots
# 2 idk
# 2 idli
# 2 idlies
# 3 idlis
# 6 ids
# 3 illnesses
# 13 ils
# 5 im
# 16 images
# 2 imagines
# 2 imans
# 10 immigrants
# 3 imo
# 5 implies
# 11 imports
# 23 impressions
# 21 improvements
# 3 improves
# 3 incarnations
# 55 inches
# 3 incidentals
# 3 incidents
# 2 inconveniences
# 3 increases
# 2 increments
# 19 india
# 147 indians
# 2 indicates
# 2 indiennes
# 9 indiens
# 9 indisches
# 28 individuals
# 18 indoors
# 2 indulge
# 3 infections
# 4 influences
# 2 informs
# 2 infusers
# 2 infuses
# 534 ingredients
# 7 injuries
# 2 inlaws
# 5 innards
# 2 innerds
# 3 inputs
# 4 inquiries
# 45 ins
# 2 insalata
# 2 insects
# 9 insides
# 5 insists
# 29 inspections
# 3 inspectors
# 5 installations
# 2 installers
# 6 instances
# 8 instincts
# 4 institutions
# 31 instructions
# 12 instructors
# 10 instruments
# 2 insults
# 6 intentions
# 2 intents
# 19 interactions
# 3 interacts
# 4 interceptions
# 3 interests
# 19 interiors
# 2 internationals
# 3 internets
# 2 interns
# 5 interpretations
# 3 interrupters
# 2 interruptions
# 2 interrupts
# 2 intersections
# 6 intervals
# 8 interviews
# 3 intestines
# 3 intricacies
# 5 introduces
# 2 invitations
# 3 involves
# 3 irks
# 2 irons
# 2 islands
# 5 isles
# 279 issues
# 3 italia
# 10 italians
# 2 italy
# 2032 items
# 20 jackets
# 2 jackie
# 5 jacks
# 3 jaipur
# 19 jalapenos
# 4 jalepenos
# 2 jamans
# 4 jamen
# 20 james
# 2 jamoons
# 4 jams
# 3 jamun
# 17 jamuns
# 22 jars
# 3 jaw
# 62 jeans
# 3 jerks
# 3 jersey
# 5 jerseys
# 2 jessica
# 4 jets
# 15 jewelers
# 5 jewels
# 4 jimmies
# 27 jitters
# 36 jobs
# 2 joe
# 17 joes
# 121 joints
# 29 jokes
# 2 jones
# 5 josh
# 2 journals
# 4 journeys
# 2 jours
# 2 judgements
# 7 judges
# 3 jugs
# 26 juices
# 12 jukeboxes
# 4 jumps
# 3 june
# 4 justifies
# 2 kabaabs
# 7 kabab
# 17 kababs
# 7 kabob
# 13 kabobs
# 12 kadai
# 4 kadhai
# 3 kafta
# 2 kalamata
# 2 kalettes
# 3 kansas
# 5 kara
# 3 karahi
# 18 kards
# 6 karen
# 3 karma
# 6 kashmiri
# 2 katana
# 4 kati
# 5 kebab
# 47 kebabs
# 3 kebob
# 2 kebobs
# 5 keema
# 54 keeps
# 2 keg
# 4 kennel
# 3 kept
# 2 kerala
# 14 ketchup
# 2 keyboards
# 33 keys
# 3 kfc
# 6 kick
# 13 kicks
# 29 kid
# 5 kiddies
# 678 kids
# 8 kills
# 4 kim
# 13 kimchi
# 45 kinda
# 169 kinds
# 6 kingfishers
# 19 kings
# 16 kinks
# 3 kismot
# 4 kisses
# 21 kitchen
# 12 kitchens
# 10 kits
# 4 kitten
# 13 kittens
# 4 kitties
# 2 kitty
# 12 knacks
# 26 knees
# 46 knew
# 4 knickknacks
# 3 knife
# 2 knights
# 17 knives
# 2 knobs
# 13 knocks
# 27 knots
# 85 know
# 71 knows
# 28 kofta
# 15 koftas
# 2 kolkata
# 5 koreans
# 50 korma
# 4 kors
# 2 kraut
# 2 kraynicks
# 2 krunchies
# 14 kudos
# 3 kulcha
# 10 kulfi
# 5 kurma
# 2 kyros
# 6 la
# 23 labels
# 23 lacks
# 188 ladies
# 3 ladyfingers
# 5 lagers
# 5 lakes
# 14 lamb
# 2 lamp
# 17 lamps
# 3 landlords
# 2 landmarks
# 2 lands
# 36 lanes
# 4 lanterns
# 11 laps
# 2 laptops
# 155 las
# 2 lasagna
# 3 lasagnas
# 2 lasers
# 5 lashes
# 2 lasses
# 15 lassi
# 7 lassies
# 6 lasts
# 4 latkes
# 11 lattes
# 7 laughs
# 6 laundromats
# 2 laundry
# 5 lauren
# 5 lava
# 46 laws
# 90 layers
# 3 lazy
# 2 leaders
# 13 leads
# 5 leagues
# 4 leaks
# 3 leans
# 2 learn
# 3 leashes
# 54 leaves
# 2 lectures
# 4 left
# 290 leftovers
# 27 legends
# 4 leggings
# 2 legit
# 32 legs
# 7 legumes
# 4 lemon
# 2 lemonades
# 19 lemons
# 2 lenders
# 3 lends
# 5 lengths
# 3 lens
# 3 lenscrafters
# 8 lenses
# 7 lentil
# 108 lentils
# 108 les
# 3 lesquels
# 13 lessons
# 49 let
# 64 lets
# 5 letters
# 3 leurs
# 183 levels
# 8 libations
# 2 librarians
# 3 licenses
# 2 licks
# 2 lidia
# 11 lids
# 6 lies
# 7 lifeguards
# 2 lifts
# 142 lights
# 83 likes
# 5 lilies
# 7 limes
# 3 limitations
# 17 limits
# 13 linens
# 3 liners
# 152 lines
# 3 lingers
# 16 links
# 16 lips
# 9 liquors
# 2 lisa
# 4 listen
# 7 listens
# 4 listings
# 24 lists
# 2 lites
# 9 livers
# 47 lives
# 3 loaders
# 42 loads
# 3 loaf
# 3 loans
# 7 loaves
# 2 lobbies
# 2 localdines
# 155 locals
# 198 locations
# 10 lockers
# 15 locks
# 3 loews
# 3 logistics
# 2 logs
# 3 lol
# 4 lollipops
# 4 look
# 11 looked
# 231 looks
# 2 loops
# 2 lords
# 6 lors
# 4 losers
# 4 loses
# 3 losses
# 3 lotions
# 850 lots
# 2 loud
# 3 lounges
# 4 love
# 86 lovers
# 71 loves
# 8 lowlights
# 3 lows
# 5 lumps
# 2 lunchables
# 64 lunches
# 4 lungs
# 3 luxuries
# 8 lyrics
# 19 mac
# 6 macaroni
# 136 machines
# 2 macros
# 3 mad
# 2 madonna
# 88 madras
# 28 magazines
# 3 magic
# 2 magnets
# 16 mahal
# 2 maharaja
# 2 maharani
# 3 mahi
# 5 maids
# 3 mailboxes
# 2 mailers
# 3 mails
# 57 mains
# 3 mainstays
# 2 majors
# 5 make
# 14 makers
# 9 makhani
# 5 maki
# 5 makings
# 14 malai
# 3 males
# 3 malia
# 29 malls
# 2 managements
# 51 managers
# 6 manages
# 5 manchuria
# 3 mancini
# 72 mango
# 8 mangoes
# 2 mangues
# 5 manhattan
# 6 manhattans
# 14 manicotti
# 5 manicures
# 2 mannequins
# 24 manners
# 4 mans
# 7 mansions
# 2 mantra
# 3 manufacturers
# 3 map
# 15 maps
# 3 mardi
# 6 margarita
# 28 margaritas
# 2 margeaux
# 6 margherita
# 4 margins
# 2 margo
# 14 maria
# 2 marigolds
# 2 marinades
# 21 markets
# 4 markings
# 44 marks
# 2 marriott
# 3 marriotts
# 2 mars
# 2 marsalas
# 10 marshalls
# 2 marshmallows
# 16 martini
# 8 martinis
# 2 marys
# 90 masala
# 26 masalas
# 27 massages
# 4 massala
# 14 masses
# 3 masterpieces
# 7 masters
# 4 mata
# 6 matar
# 20 matches
# 10 materials
# 9 mates
# 13 mats
# 5 matt
# 6 mattar
# 49 matters
# 29 matthews
# 3 mattresses
# 6 max
# 2 maxx
# 11 mayo
# 2 mayuri
# 10 maze
# 2 mb
# 3 mcbrooms
# 2 mccoy
# 5 mcdonald
# 38 mcdonalds
# 7 mckees
# 2 mckellips
# 5 mcn
# 2 md
# 3 meadows
# 12 meal
# 726 meals
# 4 mean
# 111 means
# 7 measurements
# 7 measures
# 2 meatatarians
# 144 meatballs
# 3 meatloaf
# 308 meats
# 2 meaty
# 3 mecca
# 35 mechanics
# 7 medallions
# 2 medhu
# 17 media
# 10 medications
# 4 medicines
# 4 mediocre
# 2 mediums
# 4 meds
# 2 meet
# 28 meetings
# 30 meets
# 2 meg
# 2 megan
# 19 meh
# 2 meilleurs
# 2 melons
# 5 melt
# 49 melts
# 169 members
# 6 memberships
# 3 memorabilia
# 96 memories
# 199 men
# 8 mens
# 7 mentions
# 297 menu
# 125 menus
# 2 mercedes
# 3 merchants
# 10 merits
# 12 mes
# 9 mesa
# 9 messages
# 3 messes
# 2 metals
# 13 meters
# 8 methinks
# 8 methods
# 2 metro
# 9 mets
# 5 mex
# 3 mexicans
# 2 mexico
# 2 mezbaan
# 3 mi
# 2 miami
# 4 michael
# 23 michaels
# 2 michelle
# 13 microbrews
# 6 microwaves
# 4 mid
# 4 midas
# 4 middle
# 2 midgets
# 2 midwife
# 4 midwives
# 2 miggins
# 4 migraines
# 27 mikes
# 8 mild
# 168 miles
# 2 milks
# 41 milkshakes
# 2 milky
# 2 millennials
# 4 millers
# 4 millions
# 25 mills
# 2 milwaukee
# 5 mimosa
# 6 mimosas
# 16 min
# 5 mind
# 16 minds
# 2 minerals
# 3 minerva
# 3 mines
# 2 mingle
# 2 minh
# 12 mini
# 2 minimums
# 4 minions
# 291 mins
# 6 mints
# 4 mintt
# 3 minus
# 5 minuses
# 3 minute
# 2705 minutes
# 2 miracles
# 2 mirchi
# 30 mirrors
# 2 miscommunications
# 2 misgivings
# 7 miso
# 43 miss
# 14 misses
# 2 mistaken
# 54 mistakes
# 2 misters
# 6 mitchells
# 3 mitnehmen
# 4 mittags
# 6 mix
# 5 mixers
# 18 mixes
# 4 mocha
# 6 models
# 3 modifications
# 7 moins
# 2 moisissures
# 4 mojito
# 2 mojitos
# 6 molasses
# 2 moldings
# 2 molds
# 2 molten
# 3 moly
# 14 mom
# 56 moments
# 3 momo
# 5 momos
# 15 moms
# 3 mon
# 55 mondays
# 4 moneys
# 2 mongers
# 2 monies
# 4 monitors
# 4 monkeys
# 7 monks
# 2 monro
# 6 monsters
# 2 monstrosities
# 629 months
# 2 montreal
# 3 montrealers
# 3 moods
# 2 moondogs
# 2 moonlights
# 4 moons
# 9 moonstones
# 5 mores
# 46 mornings
# 3 morons
# 4 morsels
# 14 mortons
# 2 mos
# 2 mosaic
# 2 motels
# 16 mothers
# 2 moths
# 10 motions
# 2 motives
# 3 motors
# 2 motto
# 7 mounds
# 8 mountains
# 2 mountings
# 8 mousse
# 7 mouth
# 3 mouthfuls
# 21 mouths
# 5 movements
# 30 moves
# 74 movies
# 4 mr
# 5 mrs
# 9 mt
# 2 mtl
# 25 muffins
# 2 muggy
# 19 mugs
# 5 mules
# 2 mullets
# 4 multi
# 4 multiple
# 4 multiples
# 2 mumbai
# 2 mums
# 19 munchies
# 15 murals
# 2 murgh
# 13 muscles
# 16 museums
# 260 mushrooms
# 9 mushy
# 14 musicals
# 16 musicians
# 2 muslims
# 129 mussels
# 4 mustaches
# 2 mutters
# 2 myers
# 2 na
# 3 naam
# 357 naan
# 146 naans
# 7 nachos
# 3 nacks
# 2 nada
# 2 nadu
# 91 nails
# 2 namen
# 143 names
# 46 nan
# 4 nana
# 3 nandini
# 7 nann
# 21 nans
# 2 nap
# 3 napkin
# 109 napkins
# 7 naples
# 2 nashville
# 2 nationalities
# 3 nationals
# 5 nations
# 12 natives
# 2 navratan
# 2 naysayers
# 2 nc
# 7 nd
# 12 necessities
# 2 neck
# 6 necklaces
# 3 need
# 3 needles
# 17 needless
# 328 needs
# 2 negates
# 34 negatives
# 23 neighborhoods
# 42 neighbors
# 2 nephews
# 2 nerds
# 5 nerves
# 2 nes
# 2 nests
# 6 nets
# 2 networks
# 3 newbie
# 17 newbies
# 9 newcomers
# 2 newlyweds
# 7 nibbles
# 37 nice
# 22 nicholas
# 2 nichts
# 2 nickels
# 2 nicknacks
# 2 nico
# 2 nighters
# 3 nightlife
# 7 nightmares
# 289 nights
# 2 nihari
# 3 nines
# 2 nineties
# 6 nirvana
# 3 nits
# 2 nj
# 3 nobles
# 2 nods
# 19 noises
# 4 noisy
# 12 non
# 2 nonpareils
# 2 noodle
# 337 noodles
# 3 nos
# 4 noses
# 8 nostrils
# 15 notches
# 64 notes
# 4 notice
# 11 notices
# 6 novels
# 4 novelties
# 4 novices
# 11 nowadays
# 7 nuances
# 2 nuff
# 31 nuggets
# 37 numbers
# 2 nummers
# 2 nuns
# 10 nurses
# 3 nut
# 148 nuts
# 2 ny
# 2 nyam
# 5 nyc
# 2 oats
# 3 objections
# 5 objects
# 2 obscenities
# 5 observations
# 2 obstacles
# 172 occasions
# 7 occassions
# 3 occupants
# 2 occupies
# 3 odd
# 4 oddities
# 12 odds
# 3 odors
# 2 offenders
# 234 offerings
# 220 offers
# 4 officers
# 17 offices
# 6 offs
# 23 oh
# 8 oignons
# 40 oils
# 42 ok
# 35 okay
# 3 okra
# 9 oldies
# 17 olds
# 122 olives
# 7 olympics
# 44 omelets
# 15 omelettes
# 3 omg
# 5 omlets
# 2 omlettes
# 11 omnivores
# 533 ones
# 588 onions
# 10 ons
# 2 onths
# 2 onwards
# 2 oodles
# 13 oops
# 5 openings
# 8 opens
# 2 opera
# 2 operas
# 4 operations
# 2 operators
# 21 opinions
# 15 opportunities
# 3 ops
# 5 opt
# 1765 options
# 2 optometrists
# 18 oranges
# 4 orchids
# 619 orders
# 2 organics
# 5 organizations
# 2 organizers
# 2 origin
# 4 originals
# 11 orleans
# 17 ornaments
# 2 orthodontics
# 2 orthotics
# 816 others
# 10 ounces
# 2 outages
# 33 outdoors
# 6 outfits
# 8 outings
# 33 outlets
# 16 outs
# 2 outsiders
# 2 outsides
# 13 outskirts
# 3 oven
# 8 ovens
# 4 overlooks
# 53 overs
# 568 owners
# 93 oysters
# 2 oz
# 5 pa
# 3 paces
# 23 packages
# 2 packed
# 5 packers
# 17 packets
# 54 packs
# 5 pad
# 9 paddy
# 9 pads
# 28 pages
# 19 pains
# 38 paintings
# 3 paints
# 19 pairings
# 23 pairs
# 4 pakistani
# 118 pakora
# 149 pakoras
# 64 palak
# 23 palates
# 7 pales
# 7 pallets
# 2 palms
# 7 pals
# 6 pamela
# 3 pamelas
# 9 pan
# 553 pancakes
# 3 paneer
# 7 paneers
# 6 panels
# 4 pangs
# 3 pani
# 2 pankoras
# 26 pans
# 24 panthers
# 3 panties
# 116 pants
# 3 papad
# 10 papadams
# 2 papadoms
# 4 papads
# 39 papadums
# 11 papers
# 3 papilles
# 4 pappadoms
# 12 pappadums
# 3 par
# 2 paraphernalia
# 2 paratha
# 2 parathas
# 243 parents
# 2 parfaits
# 14 parks
# 2 parmesan
# 5 participants
# 7 particles
# 3 particulars
# 186 parties
# 18 partners
# 181 parts
# 3 pasanda
# 9 passengers
# 2 passers
# 28 passes
# 3 pasta
# 112 pastas
# 2 pastrami
# 201 pastries
# 3 pastures
# 2 patches
# 7 paths
# 33 patients
# 5 patio
# 4 patios
# 2 patricks
# 4 patriots
# 295 patrons
# 2 patterns
# 6 patti
# 42 patties
# 4 patty
# 13 payments
# 10 pays
# 2 pb
# 6 pcs
# 8 peaches
# 35 peanuts
# 3 pearls
# 11 pears
# 211 peas
# 12 pecans
# 3 pedals
# 4 pedestrians
# 12 pedicures
# 2 peels
# 15 peeps
# 6 peers
# 3 pees
# 2 peeve
# 4 peeves
# 5 peices
# 4 peirogies
# 4 pekora
# 15 penguins
# 13 penn
# 11 pennies
# 3 pennsylvania
# 21 pens
# 4 peonies
# 4500 people
# 18 peoples
# 6 peppercorns
# 13 pepperoni
# 368 peppers
# 9 pepsi
# 3 perceptions
# 17 performances
# 12 performers
# 4 performs
# 13 periods
# 2 perishables
# 22 perks
# 3 permeates
# 6 permits
# 11 perogies
# 2 pers
# 12 personalities
# 18 personnel
# 8 personnes
# 15 persons
# 2 pertains
# 3 pests
# 2 petals
# 6 peters
# 2 petites
# 8 petits
# 45 pets
# 2 pews
# 4 pgh
# 2 pharmacies
# 3 philippines
# 2 phillies
# 5 phillips
# 14 pho
# 2 phobes
# 2 phoenicians
# 6 phoenix
# 2 phonecalls
# 32 phones
# 83 photos
# 3 phrases
# 2 phyllo
# 4 pianists
# 2 pianos
# 23 pices
# 5 pick
# 5 pickings
# 2 pickle
# 139 pickles
# 26 picks
# 2 picnics
# 31 pics
# 179 pictures
# 6 pie
# 712 pieces
# 3 pieds
# 6 piercings
# 129 pierogies
# 61 pies
# 9 pigeons
# 4 pigs
# 3 pilates
# 10 piles
# 42 pillows
# 2 pills
# 4 pinards
# 2 pinata
# 2 pinatas
# 2 pinches
# 3 pineapple
# 4 pineapples
# 5 pineville
# 2 pink
# 2 pinks
# 4 pins
# 12 pints
# 10 pipes
# 85 pirates
# 17 pistachios
# 22 pita
# 14 pitas
# 22 pitchers
# 9 pits
# 2 pitt
# 2 pitts
# 116 pittsburgh
# 32 pittsburghers
# 2 pittsburghians
# 2 pittsburghs
# 20 pizza
# 10 pizzas
# 11 pizzeria
# 3 placards
# 3 placemats
# 2140 places
# 4 planes
# 2 planets
# 12 planks
# 3 planners
# 53 plans
# 2 plantains
# 14 plants
# 2 plastics
# 2 platefuls
# 582 plates
# 50 plats
# 49 platters
# 3 play
# 26 players
# 5 playoffs
# 24 plays
# 3 plaza
# 5 pleasantries
# 3 pleases
# 2 pleasures
# 4 plethora
# 8 plugs
# 2 plumbers
# 6 pluses
# 7 plusieurs
# 44 pm
# 34 pockets
# 18 pods
# 4 pointers
# 181 points
# 2 pokora
# 15 police
# 8 policies
# 3 polishes
# 4 polite
# 2 politicians
# 9 politics
# 4 ponies
# 2 poodles
# 17 pools
# 2 poops
# 4 poori
# 2 pop
# 13 popadoms
# 2 popadums
# 2 popcorn
# 1 popcorns
# 1 popeyes
# 1 popodums
# 34 poppadoms
# 5 poppadums
# 6 poppers
# 1 poppodum
# 1 poppodums
# 18 pops
# 1 popsicles
# 1 populaires
# 6 populations
# 1 porcelains
# 1 porcines
# 1 porn
# 1 portals
# 1 portapottys
# 1 porters
# 1 portillo
# 1320 portions
# 4 portraits
# 3 ports
# 1 posers
# 4 positions
# 22 positives
# 1 posons
# 2 posse
# 7 possibilities
# 27 posters
# 2 postings
# 3 postmates
# 14 posts
# 1 potables
# 1 potates
# 1 potaties
# 3 potato
# 2 potatoe
# 733 potatoes
# 4 potholes
# 3 potions
# 1 potlucks
# 1 pototoes
# 24 pots
# 7 potstickers
# 1 pounces
# 1 pounders
# 64 pounds
# 6 pour
# 1 pouri
# 9 pours
# 1 pouvions
# 1 powder
# 1 powders
# 1 powerhouses
# 9 powers
# 4 ppl
# 10 practices
# 1 practises
# 16 praises
# 4 prantl
# 1 prantls
# 1 prantyl
# 1 prawn
# 55 prawns
# 3 prayers
# 10 pre
# 2 preaches
# 4 precautions
# 1 precedes
# 1 precludes
# 1 preconceptions
# 1 precooked
# 2 predecessors
# 1 prefer
# 38 preferences
# 16 prefers
# 2 prejudices
# 20 premises
# 1 premiums
# 1 prenons
# 1 preorders
# 1 prep
# 1 preparados
# 18 preparations
# 2 preparers
# 2 prepares
# 1 preps
# 1 preschoolers
# 12 prescriptions
# 9 presentations
# 1 presenters
# 17 presents
# 2 preservatives
# 1 preservers
# 1 presidents
# 1 presses
# 1 pressured
# 1 pressures
# 1 pretenses
# 3 pretensions
# 1 pretties
# 6 pretty
# 5 pretzel
# 49 pretzels
# 2 prevents
# 2 previews
# 2670 prices
# 16 pricey
# 1 pricks
# 6 prides
# 1 prima
# 27 primanti
# 1 primantibrothers
# 2 princes
# 4 principles
# 1 pringles
# 1 printers
# 13 prints
# 6 priorities
# 1 priors
# 1 prisoners
# 1 prisonniers
# 2 prisons
# 1 prix
# 1 prize
# 11 prizes
# 219 problems
# 7 procedures
# 6 proceeds
# 2 processes
# 1 proches
# 2 proclaims
# 4 produce
# 2 producers
# 1 produces
# 9 productions
# 300 products
# 1 professional
# 26 professionals
# 1 professors
# 1 profile
# 8 profiles
# 15 profits
# 1 programmes
# 14 programs
# 1 projections
# 18 projects
# 1 prolls
# 10 promises
# 1 promotes
# 12 promotions
# 1 proms
# 1 pronto
# 26 properties
# 10 proportions
# 1 propres
# 1 proprieters
# 7 proprietors
# 35 props
# 112 pros
# 2 prosciutto
# 1 proscuitto
# 1 prospects
# 4 prostitutes
# 3 protein
# 9 proteins
# 2 protesters
# 4 proud
# 2 proves
# 4 providers
# 1 provinces
# 2 provisions
# 1 provokes
# 1 proximities
# 3 prunes
# 3 ps
# 1 pts
# 6 pub
# 1 pubcrawlers
# 1 publications
# 8 pubs
# 3 pucks
# 9 puddings
# 3 puddles
# 1 puffed
# 44 puffs
# 1 puffy
# 1 pull
# 9 pulls
# 2 pulses
# 7 pumpkin
# 2 pumpkins
# 6 pumps
# 2 punches
# 1 punctures
# 1 punjab
# 2 punjabi
# 2 puns
# 3 punters
# 1 puny
# 2 pup
# 1 pupatellas
# 6 puppets
# 34 puppies
# 2 pups
# 30 purchases
# 2 purees
# 1 purim
# 1 puris
# 2 purists
# 1 purples
# 10 purposes
# 4 purses
# 1 pursuits
# 3 purveyors
# 1 push
# 3 pushes
# 1 pushovers
# 1 pushy
# 13 puts
# 1 putti
# 1 puzzle
# 7 puzzles
# 1 pyt
# 1 quaffed
# 3 quahogs
# 1 quails
# 4 qualifications
# 6 qualifies
# 13 qualities
# 4 qualms
# 34 quantities
# 41 quarters
# 4 quarts
# 1 queen
# 12 queens
# 1 quelconques
# 1 quells
# 8 quelques
# 1 ques
# 1 quesadilla
# 17 quesadillas
# 1 queso
# 324 questions
# 2 queues
# 1 quiche
# 2 quiches
# 7 quick
# 1 quickies
# 1 quid
# 1 quiets
# 2 quinoa
# 2 quips
# 4 quirks
# 3 quirky
# 3 quits
# 8 quotes
# 2 ra
# 4 rabbits
# 2 rabies
# 1 rables
# 5 races
# 1 racines
# 2 racists
# 27 racks
# 1 racquets
# 1 radiators
# 2 radishes
# 1 radius
# 2 rafters
# 1 rages
# 2 rags
# 1 rahul
# 3 raiders
# 1 raids
# 1 railings
# 1 rails
# 1 rainbows
# 1 raincoats
# 2 rains
# 1 raisens
# 1 raises
# 47 raisins
# 5 raisonnables
# 3 raisons
# 15 raita
# 1 raitas
# 1 rajbhog
# 3 ramblings
# 1 ramekins
# 26 ramen
# 2 ramps
# 2 ramsey
# 1 ran
# 1 rances
# 1 rancheros
# 1 rancid
# 1 rand
# 1 randomly
# 1 randoms
# 1 rangers
# 12 ranges
# 3 rangoons
# 2 rani
# 4 rankings
# 14 ranks
# 1 rants
# 1 rappers
# 1 rapports
# 2 raps
# 1 raptors
# 1 rarities
# 17 ras
# 3 rashers
# 1 rasmali
# 9 raspberries
# 2 rastabilities
# 1 raters
# 41 rates
# 69 ratings
# 1 ratio
# 11 rats
# 5 ravens
# 12 raves
# 22 ravioli
# 4 raviolis
# 1 ravs
# 2 raw
# 1 rawlands
# 7 rays
# 3 razor
# 2 rd
# 2 reaches
# 3 reactions
# 13 readers
# 4 readings
# 15 reads
# 2 realize
# 181 reasons
# 2 receipes
# 15 receipts
# 2 receivers
# 3 receives
# 9 receptionists
# 5 receptions
# 74 recipes
# 3 recipients
# 248 recommendations
# 2 recommends
# 20 records
# 2 recovers
# 7 reds
# 3 redskins
# 2 reeks
# 7 references
# 2 refers
# 182 refills
# 2 reflections
# 4 refreshments
# 5 refrigerators
# 3 refunds
# 4 refuses
# 34 regards
# 9 regions
# 22 registers
# 2 regret
# 9 regrets
# 122 regulars
# 2 regulations
# 2 reins
# 2 relations
# 7 relationships
# 12 relatives
# 11 relics
# 2 relies
# 5 relishes
# 2 rellenos
# 5 remains
# 5 remarks
# 3 remedies
# 2 remember
# 38 remembers
# 6 reminders
# 43 reminds
# 6 remnants
# 1 remodel
# 2 removes
# 2 renditions
# 44 renovations
# 2 rentals
# 5 renters
# 12 rents
# 60 repairs
# 3 repeats
# 6 replacements
# 5 replies
# 12 reports
# 3 representatives
# 4 reps
# 89 requests
# 14 requirements
# 3 res
# 2 rescues
# 7 resembles
# 367 reservations
# 31 residents
# 3 resides
# 3 resolutions
# 3 resorts
# 11 resources
# 5 respects
# 3 responds
# 11 responses
# 2 restants
# 10 restaraunts
# 2699 restaurants
# 3 restaurateurs
# 2 restaurents
# 5 restos
# 2 restraints
# 2 restraunts
# 24 restrictions
# 64 restrooms
# 2 rests
# 3 restuarants
# 15 resturants
# 73 results
# 8 retailers
# 2 retains
# 2 retards
# 25 returns
# 2 reuben
# 8 reubens
# 2 revelers
# 2 reviendrons
# 4 review
# 148 reviewers
# 1422 reviews
# 2 revisions
# 3 revues
# 38 rewards
# 3 reynolds
# 2 rhymes
# 2 ri
# 3 ribbons
# 18 ribs
# 4 rice
# 13 rices
# 2 rich
# 2 ricotta
# 3 riders
# 16 rides
# 3 rifles
# 2 riggies
# 10 rights
# 3 rims
# 186 rings
# 2 rinks
# 2 rips
# 5 risks
# 6 risotto
# 55 ritters
# 24 rivals
# 23 rivers
# 13 roaches
# 15 roads
# 30 roasters
# 7 roasts
# 3 robes
# 2 rockies
# 81 rocks
# 6 rods
# 2 rogan
# 8 rogers
# 11 rolands
# 6 roles
# 7 rolliers
# 646 rolls
# 2 rooftops
# 2 rookies
# 7 roommates
# 395 rooms
# 27 roots
# 7 ros
# 15 roses
# 2 rotates
# 3 rotations
# 4 roti
# 8 rotors
# 21 rounds
# 1 roundtrip
# 1 routers
# 2 routes
# 1 routines
# 1 rowdy
# 14 rows
# 2 royals
# 1 royces
# 1 roz
# 1 rstrictions
# 2 rubens
# 3 ruchi
# 2 ruebens
# 4 rugs
# 11 ruins
# 51 rules
# 3 rum
# 2 rumblings
# 11 rumors
# 14 runners
# 34 runs
# 4 rushes
# 2 russians
# 50 saag
# 2 saags
# 3 sacks
# 3 saddens
# 13 sag
# 3 sailors
# 10 saints
# 1 sake
# 3 sakes
# 2 saks
# 16 salad
# 339 salads
# 1 salata
# 164 sales
# 1 salesclerk
# 9 salesmen
# 1 saleswomen
# 1 salesy
# 3 salmon
# 2 salon
# 1 salonika
# 77 salons
# 2 saloons
# 3 salsa
# 3 salsaritas
# 2 salt
# 1 saltines
# 2 salts
# 2 sam
# 1 samantha
# 1 sambar
# 4 sambhar
# 1 sambur
# 1 sames
# 7 sammiches
# 4 sammies
# 1 sammy
# 1 samoras
# 6 samosa
# 91 samosas
# 6 sample
# 1 sampler
# 6 samplers
# 64 samples
# 5 sams
# 2 san
# 1 sancholi
# 10 sandals
# 1 sandcastle
# 1 sandhu
# 1 sandwhich
# 5 sandwhiches
# 12 sandwich
# 612 sandwiches
# 1 sandwichs
# 1 sandwitches
# 3 sanes
# 1 sang
# 16 sangria
# 1 sanitizers
# 32 sans
# 2 sara
# 1 sarcasticly
# 16 sardines
# 1 sashes
# 4 sashimi
# 16 sat
# 1 satan
# 12 satisfies
# 33 saturdays
# 64 sauce
# 3 saucers
# 778 sauces
# 4 sauerbraten
# 31 sausages
# 15 saves
# 17 savings
# 2 saw
# 2 sayings
# 3 scales
# 11 scallions
# 2 scallop
# 137 scallops
# 2 scans
# 7 scarves
# 3 scenarios
# 15 scenes
# 11 scents
# 5 schedules
# 2 schnitzel
# 10 schnitzels
# 7 schools
# 8 scissors
# 4 sconces
# 7 scones
# 18 scoops
# 8 scores
# 2 scotches
# 2 scouts
# 2 scrambles
# 2 scraps
# 6 scratches
# 8 screams
# 45 screens
# 4 screws
# 3 scrubs
# 2 sculptures
# 3 seafoods
# 4 seals
# 7 seams
# 2 searches
# 14 sears
# 7 seasonals
# 27 seasonings
# 25 seasons
# 274 seats
# 103 seconds
# 17 secrets
# 51 sections
# 2 sedans
# 23 see
# 100 seeds
# 2 seekers
# 6 seem
# 8 sees
# 2 segments
# 320 selections
# 2 self
# 4 sellers
# 2 selves
# 2 semolina
# 5 sends
# 9 seniors
# 5 sensations
# 21 senses
# 3 sensibilities
# 2 sensitivities
# 5 sensors
# 5 sentences
# 2 sentes
# 6 sentiments
# 5 separates
# 3 sergios
# 2 servants
# 6 serve
# 3 server
# 689 servers
# 151 serves
# 204 services
# 84 servings
# 14 sessions
# 67 sets
# 20 settings
# 2 setups
# 2 seventies
# 3 severs
# 2 shabby
# 19 shades
# 12 shahi
# 10 shakers
# 27 shakes
# 2 shambles
# 2 shanks
# 2 shape
# 6 shapes
# 2 sharecroppers
# 15 shares
# 2 sharwoods
# 7 shavings
# 3 shears
# 2 sheers
# 49 sheets
# 24 shells
# 4 shelters
# 49 shelves
# 5 shenanigans
# 3 shepherds
# 4 shes
# 4 shifters
# 9 shifts
# 12 shines
# 86 shirts
# 3 shits
# 119 shoes
# 12 shooters
# 5 shoots
# 4 shop
# 3 shopkeepers
# 22 shoppers
# 2 shoppes
# 162 shops
# 9 shortcomings
# 16 shorts
# 71 shots
# 23 shoulders
# 2 showerheads
# 20 showers
# 3 showings
# 6 showmars
# 121 shows
# 8 shreds
# 9 shrimp
# 16 shrimps
# 2 shrinks
# 2 shrugs
# 5 shut
# 4 shutters
# 2 shuttle
# 3 shuttles
# 2 siblings
# 2 sick
# 3 sideburns
# 351 sides
# 4 sidewalks
# 2 sideways
# 2 sightlines
# 7 sights
# 7 signals
# 4 signatures
# 2 signers
# 3 signings
# 104 signs
# 2 silks
# 4 silvers
# 2 silverwares
# 7 simmons
# 2 sin
# 10 singers
# 8 singles
# 8 sings
# 2 sinks
# 2 sins
# 14 sinuses
# 9 sips
# 3 sir
# 3 sirens
# 39 sisters
# 9 sit
# 16 sites
# 32 sits
# 18 situations
# 2 sixties
# 94 sizes
# 2 sizzlers
# 4 sizzles
# 3 skaters
# 2 skates
# 2 sketchy
# 24 skewers
# 2 skies
# 6 skillets
# 68 skills
# 15 skins
# 2 skip
# 3 skirts
# 10 skyscrapers
# 2 slabs
# 7 slacks
# 3 sleepers
# 2 sleeps
# 7 sleeves
# 4 slice
# 331 slices
# 53 sliders
# 13 slides
# 4 slings
# 3 slippers
# 5 slips
# 16 slivers
# 2 slushies
# 2 smears
# 121 smells
# 47 smiles
# 17 smokers
# 7 smokes
# 4 smoky
# 4 smooth
# 10 smoothies
# 2 smudges
# 165 snacks
# 1 snaps
# 1 snarky
# 8 sneakers
# 1 snickerdoodles
# 3 snickers
# 1 snippets
# 1 snob
# 1 snobby
# 1 snobs
# 1 snotty
# 1 snowballs
# 1 snowy
# 1 soak
# 2 soaks
# 5 soaps
# 1 soars
# 1 soba
# 1 socials
# 51 socks
# 1 soda
# 16 sodas
# 1 soecials
# 1 soemtimes
# 1 sofas
# 10 soggy
# 1 soho
# 1 soins
# 1 soirs
# 1 sol
# 6 soldiers
# 5 solid
# 1 solids
# 7 solutions
# 1 solvents
# 1 som
# 2 somedays
# 4 someones
# 16 somethings
# 8 sometimes
# 1 somewhat
# 1 sommeliers
# 11 sommes
# 1 somosas
# 62 songs
# 1 sonorans
# 30 sons
# 1 soo
# 1 soooo
# 2 sooooo
# 1 soothes
# 1 sopapillas
# 1 sopresetta
# 1 sopressata
# 1 sops
# 2 sorbets
# 7 sorry
# 61 sorts
# 1 souffle
# 1 souls
# 75 sounds
# 8 soup
# 115 soups
# 4 sour
# 12 sources
# 2 souriants
# 2 sours
# 2 southerners
# 1 souveniers
# 3 souvenirs
# 1 souviens
# 1 soynuts
# 1 sp
# 1 spa
# 46 spaces
# 4 spaetzle
# 116 spaghetti
# 1 spanakapita
# 2 spans
# 1 spares
# 1 sparkle
# 1 sparklers
# 1 spartans
# 2 spatzles
# 1 spcies
# 15 speakers
# 13 speaks
# 10 spears
# 1 specialists
# 18 specialities
# 1 specializes
# 599 specials
# 39 specialties
# 13 specifications
# 8 specifics
# 1 specify
# 1 specimens
# 1 specks
# 2 spectacles
# 1 spectators
# 2 spectrum
# 1 speeches
# 4 speeds
# 1 spell
# 2 spellings
# 2 spells
# 2 spencers
# 3 spenders
# 4 spends
# 1 spg
# 2 spheres
# 10 spice
# 1009 spices
# 2 spicey
# 1 spicies
# 15 spicy
# 1 spicyyy
# 1 spiders
# 1 spies
# 2 spikes
# 6 spills
# 1 spines
# 4 spins
# 28 spirits
# 1 spit
# 2 spits
# 1 splashes
# 2 splatters
# 2 splinters
# 3 splits
# 2 spoonfuls
# 48 spoons
# 219 sports
# 5 spot
# 204 spots
# 2 spouses
# 21 spreads
# 2 sprigs
# 2 springrolls
# 6 springs
# 15 sprinkles
# 54 sprouts
# 2 spuds
# 21 squares
# 2 squeals
# 2 srees
# 2 sriracha
# 4 st
# 11 stacks
# 8 stadiums
# 4 staffed
# 4 staffers
# 16 staffs
# 7 stages
# 29 stains
# 2 staircases
# 46 stairs
# 7 stakes
# 5 stallings
# 13 stalls
# 2 stamoolis
# 5 stamps
# 190 standards
# 2 standings
# 14 standouts
# 23 stands
# 2 stans
# 4 staple
# 74 staples
# 2 star
# 244 starbucks
# 8 stares
# 1 starpoints
# 2162 stars
# 171 starters
# 1 startle
# 27 starts
# 1 startups
# 1 starwoods
# 1 staryucks
# 7 statements
# 107 states
# 44 stations
# 2 stats
# 10 statues
# 28 stays
# 4 steak
# 12 steakhouses
# 80 steaks
# 2 steals
# 192 steelers
# 2 steins
# 67 steps
# 2 stereotypes
# 4 steroids
# 2 stew
# 6 stews
# 24 stickers
# 129 sticks
# 5 stillers
# 2 stingy
# 15 stinks
# 2 stipulations
# 3 stitches
# 2 stockings
# 7 stocks
# 5 stomachs
# 27 stones
# 22 stools
# 4 stop
# 22 stops
# 4 storefronts
# 386 stores
# 49 stories
# 2 storms
# 4 stouffers
# 2 stragglers
# 7 strands
# 30 strangers
# 3 straps
# 55 strawberries
# 2 straws
# 3 strays
# 4 streaks
# 60 streets
# 4 strengths
# 3 stretches
# 16 strikes
# 14 strings
# 3 strip
# 6 stripes
# 2 strippers
# 61 strips
# 2 strollers
# 2 strudels
# 3 struts
# 159 students
# 6 studios
# 3 stuff
# 11 stuffed
# 4 stuffers
# 3 stuffings
# 9 stuffs
# 55 styles
# 3 stylings
# 67 stylists
# 2 styrofoam
# 6 sub
# 4 subjects
# 28 subs
# 2 substitutes
# 11 substitutions
# 3 subtitles
# 2 suburbanites
# 11 suburbs
# 4 suckers
# 113 sucks
# 8 suffers
# 7 suffice
# 4 sugars
# 199 suggestions
# 3 suggests
# 17 suites
# 76 suits
# 2 sum
# 9 summers
# 12 sums
# 2 sunday
# 67 sundays
# 9 sundries
# 3 sunflowers
# 4 sunglasses
# 4 super
# 7 superb
# 13 supercuts
# 8 supermarkets
# 3 supervisors
# 4 suppliers
# 67 supplies
# 2 supporters
# 4 supports
# 4 surfaces
# 4 surgeries
# 2 surpasses
# 27 surprises
# 35 surroundings
# 4 surrounds
# 2 survives
# 4 sushi
# 12 suspects
# 3 suspicions
# 3 swatches
# 9 swears
# 9 sweaters
# 5 sweats
# 2 sweatshirts
# 4 sweet
# 5 sweeteners
# 135 sweets
# 2 swimmers
# 2 swims
# 2 swimsuits
# 3 swings
# 3 swipes
# 2 swirls
# 6 switches
# 3 swords
# 7 symptoms
# 9 syrup
# 4 syrups
# 10 systems
# 2 tablecloth
# 2 tableclothes
# 32 tablecloths
# 1446 tables
# 4 tablespoons
# 3 tabletops
# 4 tablets
# 4 tabs
# 7 taco
# 43 tacos
# 4 tactics
# 7 tad
# 10 tag
# 21 tags
# 2 tahoora
# 2 taillights
# 4 tailors
# 6 tails
# 16 taj
# 19 takeaways
# 3 takeouts
# 3 talents
# 3 tales
# 22 talks
# 6 tamales
# 111 tandoori
# 3 tandoors
# 7 tandori
# 3 tangy
# 4 tapas
# 3 tapes
# 5 tapestries
# 21 taps
# 2 taqueria
# 8 targets
# 7 tariens
# 3 tarts
# 4 tasks
# 3 tassies
# 15 tastebuds
# 488 tastes
# 5 tastings
# 14 tasty
# 4 taters
# 20 taxes
# 6 teachers
# 24 teams
# 2 teapots
# 30 tears
# 36 teas
# 11 technicians
# 13 techniques
# 15 teenagers
# 25 teens
# 7 tees
# 2 teeters
# 30 teeth
# 24 televisions
# 5 tell
# 69 tells
# 2 tels
# 2 temp
# 4 tempe
# 14 temperatures
# 3 tempora
# 10 temps
# 15 ten
# 19 tenants
# 2 tend
# 2 tendencies
# 55 tenders
# 2 tendons
# 35 tends
# 3 tentacles
# 5 tents
# 2 terminals
# 207 terms
# 2 terriers
# 2 terrors
# 4 tes
# 5 tessaro
# 4 tessaros
# 16 tests
# 5 texas
# 5 textiles
# 26 textures
# 4 th
# 18 thai
# 12 thali
# 8 thalis
# 2 thank
# 2 thanked
# 494 thanks
# 132 thats
# 23 theaters
# 3 theatre
# 2 theatres
# 2 themes
# 3 therapists
# 21 theres
# 2 thick
# 7 thieves
# 6 thighs
# 2 thin
# 4 thingies
# 2327 things
# 5 think
# 21 thinks
# 2 thins
# 12 thirds
# 2 though
# 35 thoughts
# 23 thousands
# 3 threads
# 5 thrills
# 2 thrives
# 2 throats
# 3 throes
# 9 thrones
# 3 throngs
# 8 throws
# 4 thru
# 3 thugs
# 8 thumbprints
# 73 thumbs
# 3 thums
# 2 thurs
# 14 thursdays
# 138 tickets
# 4 tidbits
# 2 tie
# 3 tiers
# 18 ties
# 2 tiffins
# 2 tights
# 26 tikka
# 2 tikki
# 18 tiles
# 3 tillies
# 33 timers
# 3181 times
# 4 timings
# 3 tines
# 3 tins
# 2 tiny
# 8 tions
# 9 tip
# 118 tips
# 7 tiramisu
# 117 tires
# 3 titans
# 4 titles
# 4 toasts
# 4 todays
# 2 todd
# 13 toddlers
# 5 toenails
# 19 toes
# 14 tofu
# 3 togethers
# 4 toiles
# 11 toiletries
# 10 toilets
# 2 toilettes
# 5 tokens
# 2 told
# 2 tolls
# 3 tomates
# 15 tomato
# 2 tomatoe
# 294 tomatoes
# 2 toms
# 12 tones
# 4 tongs
# 3 tongues
# 258 tons
# 20 tools
# 4 tooth
# 2 toothpicks
# 2 tooths
# 4 topics
# 348 toppings
# 47 tops
# 2 torn
# 14 torte
# 6 tortes
# 40 tortillas
# 4 totals
# 68 tots
# 34 touches
# 12 toujours
# 9 tour
# 46 tourists
# 2 tournaments
# 7 tours
# 5 toutes
# 3 touts
# 151 towards
# 83 towels
# 11 towers
# 30 towners
# 5 townes
# 9 towns
# 2 toy
# 16 toys
# 4 traces
# 9 tracks
# 4 trades
# 12 traditions
# 2 trailers
# 18 trails
# 10 trainers
# 13 trains
# 3 traits
# 4 tram
# 7 trams
# 2 trans
# 4 transactions
# 5 translates
# 3 translations
# 2 transmissions
# 1 transplants
# 3 transports
# 1 trappings
# 4 traps
# 1 trash
# 1 trashes
# 2 trattoria
# 1 traveler
# 25 travelers
# 2 travellers
# 16 travels
# 64 trays
# 1 tre
# 17 treadmills
# 6 treadquarters
# 10 treasures
# 24 treatments
# 103 treats
# 16 trees
# 2 trek
# 2 tremens
# 1 tremors
# 1 trendies
# 10 trends
# 3 trendy
# 8 tres
# 1 triages
# 7 triangles
# 12 tricks
# 1 triers
# 53 tries
# 1 trifecta
# 1 trifolata
# 2 triggers
# 2 trim
# 8 trimmings
# 4 trims
# 1 trinacria
# 5 trinkets
# 1 trio
# 2 trios
# 2 triple
# 98 trips
# 1 trivialities
# 1 troops
# 1 trophies
# 1 tropics
# 8 troubles
# 2 troughs
# 4 truckers
# 18 trucks
# 4 truffles
# 2 truly
# 1 trumpets
# 2 trumps
# 2 trunks
# 6 trust
# 1 truths
# 59 try
# 1 tryin
# 2 tryon
# 1 tsang
# 6 tshirts
# 3 tub
# 5 tubes
# 3 tubs
# 1 tudiants
# 6 tues
# 40 tuesdays
# 3 tulips
# 2 tumblers
# 1 tumes
# 9 tummies
# 1 tummy
# 6 tums
# 7 tuna
# 1 tunas
# 21 tunes
# 1 tuneup
# 1 tunics
# 4 tunnels
# 1 turban
# 1 turbo
# 1 tureens
# 2 turkeys
# 3 turnips
# 2 turnovers
# 39 turns
# 1 turquoises
# 1 turtles
# 1 tutti
# 1 tuxedo
# 44 tvs
# 1 twangs
# 3 tweaks
# 1 tweens
# 2 tweezers
# 1 twelve
# 7 twenties
# 1 twigs
# 2 twinings
# 5 twins
# 2 twinsets
# 8 twisters
# 13 twists
# 1 twitterers
# 1 twp
# 1 ty
# 1 tykes
# 2 type
# 289 types
# 1 typicals
# 1 typifies
# 1 typiques
# 1 tyres
# 2 tzle
# 1 tzotchkes
# 2 udon
# 2 udupi
# 2 uh
# 1 ukuleles
# 1 ulcers
# 1 ultrasounds
# 1 um
# 2 umbrellas
# 1 umi
# 2 ums
# 1 unawares
# 1 uncc
# 2 uncles
# 1 underlies
# 1 undermines
# 1 underpants
# 4 understands
# 1 underwhelms
# 2 undesirables
# 4 undies
# 1 unes
# 2 unicorns
# 1 unitedstaders
# 14 units
# 1 universes
# 3 universities
# 1 unpleasantries
# 1 uns
# 1 unsavories
# 1 unsavouries
# 1 unterzukommen
# 1 upcharges
# 8 updates
# 8 upgrades
# 1 upma
# 1 upon
# 25 ups
# 1 upsells
# 2 upset
# 76 upstairs
# 1 upstars
# 11 upwards
# 2 urbana
# 2 urbanites
# 5 urges
# 3 urinals
# 1 usa
# 12 users
# 16 uses
# 10 ushers
# 1 ussies
# 5 usuals
# 35 utensils
# 7 utilities
# 1 vacancies
# 3 vacations
# 1 vacay
# 6 vaccinations
# 7 vaccines
# 1 vaccuums
# 1 vacuums
# 10 vada
# 2 vadai
# 7 vadas
# 1 vagaries
# 1 vagas
# 1 vaisakhi
# 1 valencia
# 35 valentines
# 1 valet
# 7 valets
# 2 validates
# 5 valley
# 4 valleys
# 2 valuables
# 10 values
# 1 vamps
# 1 vans
# 1 vapors
# 1 vargrants
# 1 variables
# 3 variants
# 30 variations
# 37 varies
# 2 varietals
# 140 varieties
# 4 varities
# 6 vases
# 1 vat
# 1 vats
# 1 veags
# 1 veal
# 1 veces
# 1 veers
# 26 veg
# 52 vegan
# 1 veganese
# 50 vegans
# 85 vegas
# 3 vegatables
# 4 veges
# 548 vegetables
# 206 vegetarians
# 2 veggetables
# 17 veggie
# 1 veggieheads
# 501 veggies
# 1 vegheads
# 2 vegies
# 1 vegititables
# 18 vehicles
# 1 vein
# 5 veins
# 1 veltres
# 1 velvet
# 31 vendors
# 3 ventos
# 6 vents
# 7 ventures
# 2 venue
# 25 venues
# 1 verboten
# 1 verdes
# 1 verges
# 1 verifies
# 4 vermicelli
# 4 verres
# 4 vers
# 3 versailles
# 2 verses
# 56 versions
# 2 verts
# 1 vessels
# 2 vestiges
# 2 vests
# 4 vet
# 6 veterans
# 1 vetinarians
# 33 vets
# 1 vey
# 13 vibe
# 16 vibes
# 1 vibrates
# 2 vibrations
# 1 vic
# 1 vices
# 1 vicks
# 5 victims
# 2 victoria
# 2 victories
# 1 vidai
# 2 video
# 50 videos
# 1 vides
# 1 vids
# 6 vietnam
# 1 vietnamese
# 1 viets
# 52 views
# 1 vik
# 1 vikings
# 1 villa
# 3 villages
# 2 villas
# 4 vincents
# 29 vindaloo
# 1 vindalooo
# 3 vindaloos
# 3 vinegar
# 6 vinegars
# 1 vines
# 1 vineyards
# 1 vinnies
# 1 vino
# 4 vins
# 1 vintages
# 2 vinyasa
# 1 vinylrecords
# 14 violations
# 2 vips
# 1 virginia
# 2 virtues
# 1 virus
# 1 viruses
# 1 visa
# 1 visions
# 1 visionworks
# 34 visit
# 2 visites
# 43 visitors
# 253 visits
# 1 visuals
# 4 vitals
# 1 vitamin
# 4 vitamins
# 1 vito
# 1 vives
# 2 vocals
# 1 vocations
# 1 voice
# 3 voicemails
# 14 voices
# 1 volcanos
# 7 volumes
# 17 volunteers
# 4 vons
# 1 voodoo
# 1 vores
# 1 vors
# 1 votives
# 9 vouchers
# 1 vow
# 1 vowed
# 2 vowels
# 1 voyages
# 1 voyons
# 3 vs
# 3 vultures
# 1 vw
# 1 waa
# 1 waaaaaay
# 1 waana
# 1 wada
# 1 wads
# 5 wafers
# 1 waffle
# 29 waffles
# 4 wafts
# 1 wagers
# 1 wages
# 1 wahres
# 1 waistcoats
# 1 waistlines
# 1 waists
# 15 wait
# 348 waiters
# 1 waitors
# 131 waitresses
# 33 waits
# 11 waitstaff
# 1 waitstaffs
# 1 waiyets
# 1 waldhorns
# 5 wales
# 7 walgreens
# 4 walk
# 6 walkers
# 36 walks
# 4 walkways
# 1 wallet
# 6 wallets
# 1 walleye
# 243 walls
# 2 walnut
# 25 walnuts
# 1 walt
# 19 walters
# 3 wanderers
# 3 wanders
# 3 wanna
# 2 want
# 3 wards
# 8 waren
# 8 wares
# 1 warm
# 4 warmers
# 6 warms
# 1 warmth
# 1 warn
# 3 warnings
# 5 warranties
# 13 warrants
# 1 wars
# 1 wasabi
# 2 wash
# 1 washclothes
# 29 washers
# 8 washes
# 1 washings
# 6 washrooms
# 6 wasnt
# 1 watchers
# 14 watches
# 1 waterholes
# 1 watermelons
# 1 waterparks
# 81 waters
# 1 waterworks
# 1 watkins
# 1 watts
# 2 wavers
# 13 waves
# 2 wavy
# 1 wawa
# 1 wax
# 7 waxes
# 116 ways
# 2 weaknesses
# 1 wealth
# 2 weapons
# 7 wears
# 1 weathers
# 1 web
# 2 website
# 8 websites
# 13 weddings
# 21 wedges
# 3 wedgies
# 19 wednesdays
# 1 wee
# 5 weeds
# 1 weekday
# 38 weekdays
# 220 weekends
# 13 weeknights
# 498 weeks
# 2 wegmans
# 1 weighs
# 30 weights
# 1 weiners
# 1 weinershnitzel
# 1 weirdo
# 1 weirdos
# 1 weirds
# 1 welches
# 3 welcomes
# 2 well
# 16 wells
# 1 wen
# 1 wendy
# 1 wendys
# 1 wermens
# 1 westeners
# 6 westerners
# 1 westerns
# 5 westin
# 7 westins
# 1 wet
# 1 wf
# 1 wha
# 1 whatnots
# 22 whats
# 1 whatsits
# 1 wheats
# 2 wheel
# 24 wheels
# 1 whereabouts
# 10 whereas
# 1 wherein
# 1 wheres
# 1 whilst
# 3 whim
# 1 whiners
# 1 whips
# 1 whiskey
# 1 whiskeys
# 1 whispers
# 5 whistles
# 11 whites
# 2 whiteys
# 1 whits
# 2 whoa
# 5 wholefoods
# 1 wholes
# 2 wholesalers
# 9 wholeys
# 1 wholleys
# 5 whoops
# 1 whoopsies
# 1 wiches
# 1 widgets
# 1 wieners
# 12 wifi
# 1 wigs
# 1 wilds
# 10 williams
# 1 wilsons
# 1 wimps
# 4 win
# 121 windows
# 1 wineglasses
# 92 wines
# 2 wingharts
# 676 wings
# 9 winners
# 16 wins
# 2 winters
# 1 wiperblades
# 4 wipers
# 3 wipes
# 3 wires
# 1 wisecracks
# 2 wish
# 2 wished
# 10 wishes
# 1 witchy
# 2 withdrawals
# 5 wives
# 1 wizards
# 1 wkends
# 1 wobbles
# 4 woes
# 3 wolves
# 1 womans
# 200 women
# 4 womens
# 1 wonderdogs
# 17 wonders
# 1 wont
# 8 wontons
# 4 woodies
# 74 woodlands
# 29 woods
# 1 wools
# 193 words
# 1 worked
# 1 workerbees
# 230 workers
# 1 workings
# 4 workouts
# 2 workplaces
# 73 works
# 3 workshops
# 2 workstations
# 10 worlds
# 6 worms
# 1 worn
# 38 worries
# 1 worst
# 1 worthes
# 4 wouldnt
# 1 wouls
# 1 wounds
# 26 wow
# 2 wows
# 2 wowzers
# 1 wrap
# 5 wrappers
# 1 wrappings
# 92 wraps
# 1 wreaths
# 2 wrinkles
# 1 wrists
# 4 writers
# 1 writes
# 1 writings
# 5 wrong
# 1 wtf
# 1 wurst
# 3 wursts
# 2 www
# 1 xanax
# 3 ya
# 1 yacht
# 1 yaha
# 1 yam
# 3 yams
# 10 yards
# 2 yarns
# 1 yaselves
# 1 yck
# 1 ye
# 3 yea
# 12 yeah
# 2234 years
# 1 yeasts
# 1 yell
# 1 yellows
# 3 yells
# 11 yelp
# 142 yelpers
# 2 yelpsters
# 2 yenglings
# 5 yep
# 382 yes
# 1 yeungs
# 2 yields
# 25 yikes
# 2 yinz
# 23 yinzers
# 1 yirachefe
# 1 yiu
# 2 yo
# 9 yogurt
# 1 yogurts
# 1 yokels
# 1 yokes
# 1 yolo
# 1 yonks
# 4 yorkers
# 1 younglings
# 2 youngsters
# 1 yousef
# 1 youtube
# 1 yowzers
# 2 yr
# 1 yrs
# 1 yu
# 1 yuck
# 6 yuenglings
# 1 yuengs
# 23 yum
# 1 yumm
# 3 yummers
# 2 yummies
# 1 yummmm
# 26 yummy
# 4 yums
# 1 yuns
# 1 yup
# 3 yuppies
# 1 yuuuuuumy
# 1 yuva
# 1 zabars
# 2 zales
# 1 zayres
# 3 zen
# 1 zillions
# 1 zings
# 1 zingy
# 3 zombies

# %%
print ("Training the random forest...")
from sklearn.ensemble import RandomForestClassifier

# Initialize a Random Forest classifier with 100 trees
forest = RandomForestClassifier(n_estimators = 100) 

# Fit the forest to the training set, using the bag of words as 
# features and the sentiment labels as the response variable
#
# This may take a few minutes to run
forest = forest.fit( train_data_features, train["Polarity"] )
# Out:
# Training the random forest...

# %%
feasure = np.array(vocab)
importances = forest.feature_importances_
index = importances.argsort()[-50:]
index
# Out:
# array([1034, 4181, 4144,  132, 2323, 2612, 4581, 4003, 4042, 1899, 1345,
#        2782, 2209, 4322, 3075, 3041, 2896, 2306,  507, 4281, 1580, 4004,
#        1082, 2753,  716, 1086, 4943, 3604, 2294, 3001, 2394, 4166, 1515,
#        1513,  756, 2802, 3590, 2210, 1130, 2604, 2803, 1956,  508, 3623,
#        2603, 3057, 3453, 3942, 1051, 1195])

# %%
#top 50 words
feasure[index]
# Out:
# array(['cubes', 'tastes', 'tables', 'appetizers', 'mango', 'nan',
#        'vegetarians', 'stars', 'stores', 'hours', 'entrees', 'owners',
#        'lentils', 'toppings', 'potatoes', 'poppadoms', 'people', 'mains',
#        'buffet', 'times', 'fries', 'starters', 'dans', 'options',
#        'chickpeas', 'das', 'years', 'sandwiches', 'madras', 'plates',
#        'meals', 'tandoori', 'flavours', 'flavors', 'chutneys', 'pakora',
#        'samosas', 'les', 'des', 'naans', 'pakoras', 'indians', 'buffets',
#        'sauces', 'naan', 'portions', 'restaurants', 'spices', 'curries',
#        'dishes'],
#       dtype='<U17')

# %%
# Read the test data


# Verify that there are 25,000 rows and 2 columns
print (test.shape)

# Create an empty list and append the clean reviews one by one
num_reviews = len(test["Review"])
clean_test_reviews = [] 

print ("Cleaning and parsing the test set movie reviews...\n")
for i in range(0,num_reviews):
    if( (i+1) % 1000 == 0 ):
        print ("Review %d of %d\n" % (i+1, num_reviews))
    clean_review = review_to_words( test["Review"][i] )
    clean_test_reviews.append( clean_review )

# Get a bag of words for the test set, and convert to a numpy array
test_data_features = vectorizer.transform(clean_test_reviews)
test_data_features = test_data_features.toarray()

# Use the random forest to make sentiment label predictions
result = forest.predict(test_data_features)

# Copy the results to a pandas dataframe with an "id" column and
# a "sentiment" column
output = pd.DataFrame( data={"id":test["Business_id"], "Polarity":result} )
output
# Out:
# (293, 4)
# Cleaning and parsing the test set movie reviews...
# /usr/local/lib/python3.4/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 170 of the file /usr/lib/python3.4/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
#      Polarity                         id
# 0           0  b'wLlxavQWA1-d9Pcwp9nbLg'
# 1           0  b'1_lU0-eSWJCRvNGk78Zh9Q'
# 2           0  b'PSlOtPIo28BvWOzdLmRRRQ'
# 3           0  b'v3r3IFCiWYrae-n3vyccSA'
# 4           0  b'QjMZ3Gt4c-vS2uVUWQrVbw'
# 5           0  b'YRDKsBFYP7G0E8BLJKIkvA'
# 6           0  b'3OViesv3-RkPDyvdxW16sg'
# 7           0  b'_yZbIA76UR0cIgoq0jM5zQ'
# 8           0  b'P1fJb2WQ1mXoiudj8UE44w'
# 9           0  b'3UL1To_gn_eOY5iFH5oBxA'
# 10          0  b'xUf11yTcoRagwNiJcY8GAA'
# 11          0  b'sNmQJQWEVGheCnw5Tf4Phg'
# 12          0  b'-xymuZ9qLUwGQBD9FxldGQ'
# 13          0  b'-iVcmhjfq79QoTWzrb6pKg'
# 14          0  b'3G8_qVxaTkkO5b70_H8YDA'
# 15          0  b'OWNkVvDfREC1_6S3jS-7Ug'
# 16          0  b'W7ysp8GLCBrs0GXIVwAcBQ'
# 17          0  b'_4jd_mYZ8EmE7Hl7AOyWzA'
# 18          0  b'sB0yyxeBcVhRxGd-lwR4yg'
# 19          0  b'XhROKVaYQU1rxKMM4Vlrjg'
# 20          0  b'xO09rJXkqonSRzUzcwjoFQ'
# 21          0  b'FUZnJQbb0tHit2U6wFkAIw'
# 22          0  b'WD7TUnO7ExNJahLN4p3bMA'
# 23          0  b'YsfWJDvLXiY8xbP9r9qK1A'
# 24          0  b'J011r7mUV1QhgLJ7GkrtMw'
# 25          0  b'1n0n_-Iz0e3iVpH8sereiA'
# 26          0  b'fHovFhbYJcy6y4oosMhM_A'
# 27          0  b'U12GISjtUQ7j9KMJ0nfnDQ'
# 28          1  b'QMX1ssofSveU3qhVAKLnXA'
# 29          0  b'MCSp40xkhRoNw2OVtRSG6w'
# ..        ...                        ...
# 263         1  b'NKZl3NNtObpnPF7grstzpw'
# 264         1  b'GJQvDc5DZQeXKmG_5Tcbug'
# 265         1  b'vqylP0gus0xK57G7-Yh3Hg'
# 266         1  b'wy_R4crNr1BH0CP87y9UHQ'
# 267         1  b'D33RKp1Wdf9TmZBiStae5A'
# 268         1  b'8AS3dlN-Y3UG26elbF-jgg'
# 269         1  b'DmADRy3mVWKmNt-X0cbmwg'
# 270         1  b'gkWEjZIVcrUerEzed6IKpg'
# 271         1  b'WdcWkru51EErR9HqmfSqqw'
# 272         1  b'_n-Rb4H20FA1WLPfZimRiw'
# 273         1  b'6F_3fSUPUtw_9b93g9GEmw'
# 274         1  b'NKSA0em3dHSGTyo6Eu-Waw'
# 275         1  b'c6D9JQpVb3_YTQxTPcQeeA'
# 276         0  b'Z-NObtOLb_OZVQghuWLIjg'
# 277         1  b'YcDmBScHtp9-hrJkpzpfHA'
# 278         1  b'aiUid8bYNV8XDiSk7EKOIw'
# 279         1  b'QwrWxzfGdv_bMiFrDaV4sA'
# 280         1  b'H-99nG_KfynWPXh84TKj8A'
# 281         1  b'PsQV3uWg99lJXZpYPdpDGw'
# 282         1  b'BSk-BrZGvtRGxy1aFzSMCA'
# 283         1  b'howeWJgjp0m25gY4gRSsYA'
# 284         1  b'5dUDkaxm5FdQanoNkP86KQ'
# 285         1  b'nuCgH96Tfe6CFXznvmKdhA'
# 286         0  b'P6O4JBwMN6fZhUQiAx43Kw'
# 287         1  b'KvH0MN2F6J3oBAOibsBjEQ'
# 288         1  b'K9ANxXrqLT9og35blpRTeg'
# 289         0  b'SvDuRiDpLpr5VRm3aqw8Eg'
# 290         1  b'7N713OtnkPkS63VrWwtjWw'
# 291         1  b'eal7Vfv39cAUVIyiJJ--Jw'
# 292         1  b'0KU-tajtS1YDaqNN_EmPEA'
#
# [293 rows x 2 columns]

# %% [markdown]
# ## accuracy

# %%
i, j = output.shape
1- sum(pow(test["Polarity"]- output["Polarity"],2))/i
# Out:
# 0.96245733788395904
